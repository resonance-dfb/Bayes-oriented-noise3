# %%
import random
from torchvision import datasets, transforms
import torch.optim as optim
import torch.nn as nn
import pandas as pd
#import imageio
import numpy as np
import torch
from torch.autograd import Variable
import torch.nn.functional as F
import torch.utils.data as Data

import matplotlib.pyplot as plt
# %matplotlib inline
import math

import torchvision
import torchvision.transforms as transforms
import optuna  #载入optuna优化包

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Image preprocessing modules
transform = transforms.Compose([
    transforms.Pad(4),
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32),
    transforms.ToTensor()])

# CIFAR-10 dataset
train_dataset = torchvision.datasets.CIFAR10(root='../../data/',
                                             train=True,
                                             transform=transform,
                                             download=True)

test_dataset = torchvision.datasets.CIFAR10(root='../../data/',
                                            train=False,
                                            transform=transforms.ToTensor())

# Data loader
train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                           batch_size=100,
                                           shuffle=True)

test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                          batch_size=100,
                                          shuffle=False)


##optuna######
###耗费时间的过程。。。。。。。。。。。。。。。
# Define a basic convolutional layer
# 定义 ExLU 激活函数，sigma 是可学习参数
class ExLU(nn.Module):
    def __init__(self, seqFlag, trial):
        super(ExLU, self).__init__()
        # 通过 Optuna 选择 sigma 参数，范围为 2.0 到 6.0
        self.sigma = nn.Parameter(torch.tensor(trial.suggest_float(f'sigma_{seqFlag}', 2.0, 6.0), dtype=torch.float32))

    def forward(self, x):
        return torch.where(x >= 0, x, x * torch.exp(x / self.sigma))


def conv3x3(in_channels, out_channels, stride=1):
    return nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False)


# 定义ResNet模型
class ResNet(nn.Module):
    def __init__(self, trial, num_classes=10):
        super(ResNet, self).__init__()
        self.conv1 = conv3x3(3, 16)
        self.bn1 = nn.BatchNorm2d(16)
        self.custom1 = ExLU(1, trial)  # 自定义激活函数层

        # Layer 1
        self.layer1_conv1 = conv3x3(16, 16)
        self.layer1_bn1 = nn.BatchNorm2d(16)
        self.layer1_conv2 = conv3x3(16, 16)
        self.layer1_bn2 = nn.BatchNorm2d(16)
        self.layer1_extra_conv1 = conv3x3(16, 16)
        self.layer1_extra_bn1 = nn.BatchNorm2d(16)
        self.layer1_extra_conv2 = conv3x3(16, 16)
        self.layer1_extra_bn2 = nn.BatchNorm2d(16)
        self.gelub11 = ExLU(2, trial)
        self.gelub12 = ExLU(3, trial)
        self.gelub13 = ExLU(4, trial)
        self.gelub14 = ExLU(5, trial)

        # Layer 2
        self.layer2_conv1 = conv3x3(16, 32, stride=2)
        self.layer2_bn1 = nn.BatchNorm2d(32)
        self.layer2_conv2 = conv3x3(32, 32)
        self.layer2_bn2 = nn.BatchNorm2d(32)
        self.layer2_extra_conv1 = conv3x3(16, 32, stride=2)  # 调整residual的通道数
        self.layer2_extra_bn1 = nn.BatchNorm2d(32)
        self.layer2_extra_conv2 = conv3x3(32, 32)
        self.layer2_extra_bn2 = nn.BatchNorm2d(32)
        self.gelub21 = ExLU(6, trial)
        self.gelub22 = ExLU(7, trial)
        self.gelub23 = ExLU(8, trial)
        self.gelub24 = ExLU(9, trial)
        self.layer2_downsample = nn.Sequential(
            nn.Conv2d(16, 32, kernel_size=1, stride=2, bias=False),
            nn.BatchNorm2d(32)
        )

        # Layer 3
        self.layer3_conv1 = conv3x3(32, 64, stride=2)
        self.layer3_bn1 = nn.BatchNorm2d(64)
        self.layer3_conv2 = conv3x3(64, 64)
        self.layer3_bn2 = nn.BatchNorm2d(64)
        self.layer3_extra_conv1 = conv3x3(32, 64, stride=2)  # 调整residual的通道数
        self.layer3_extra_bn1 = nn.BatchNorm2d(64)
        self.layer3_extra_conv2 = conv3x3(64, 64)
        self.layer3_extra_bn2 = nn.BatchNorm2d(64)
        self.gelub31 = ExLU(10, trial)
        self.gelub32 = ExLU(11, trial)
        self.gelub33 = ExLU(12, trial)
        self.gelub34 = ExLU(13, trial)

        self.layer3_downsample = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=1, stride=2, bias=False),
            nn.BatchNorm2d(64)
        )

        self.avg_pool = nn.AvgPool2d(8)
        self.fc = nn.Linear(64, num_classes)

    def forward(self, x):
        # Layer 0
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.custom1(out)

        # Layer 1
        residual = out
        out = self.layer1_conv1(out)
        out = self.layer1_bn1(out)
        out = self.gelub11(out)
        out = self.layer1_conv2(out)
        out = self.layer1_bn2(out)
        out += residual
        out = self.gelub12(out)

        residual = out
        out = self.layer1_extra_conv1(out)
        out = self.layer1_extra_bn1(out)
        out = self.gelub13(out)
        out = self.layer1_extra_conv2(out)
        out = self.layer1_extra_bn2(out)
        out += residual
        out = self.gelub14(out)

        # Layer 2
        residual = out
        out = self.layer2_conv1(out)
        out = self.layer2_bn1(out)
        out = self.gelub21(out)
        out = self.layer2_conv2(out)
        out = self.layer2_bn2(out)
        out = self.gelub22(out)
        residual = self.layer2_downsample(residual)
        out += residual
        out = self.gelub22(out)

        residual = out
        out = self.layer2_extra_conv2(out)
        out = self.layer2_extra_bn2(out)
        out = self.gelub23(out)
        out = self.layer2_extra_conv2(out)
        out = self.layer2_extra_bn2(out)
        out += residual
        out = self.gelub24(out)

        # Layer 3
        residual = out
        out = self.layer3_conv1(out)
        out = self.layer3_bn1(out)
        out = self.gelub31(out)
        out = self.layer3_conv2(out)
        out = self.layer3_bn2(out)
        residual = self.layer3_downsample(residual)
        out += residual
        out = self.gelub32(out)

        residual = out
        out = self.layer3_extra_conv2(out)
        out = self.layer3_extra_bn2(out)
        out = self.gelub33(out)
        out = self.layer3_extra_conv2(out)
        out = self.layer3_extra_bn2(out)
        out += residual
        out = self.gelub34(out)

        out = self.avg_pool(out)
        out = out.view(out.size(0), -1)
        out = self.fc(out)
        return out


def update_lr(optimizer, lr):
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr


learning_rate = 0.001
num_epochs = 100


# 定义目标函数
def objective(trial):
    # 模型实例化
    model = ResNet(trial)
    model.to(device)
    curr_lr = learning_rate
    # 损失函数和优化器
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=curr_lr)  # 保持 Adam 优化器

    #history = {'train_loss': [], 'valid_loss': [], 'train_acc': [], 'valid_acc': []}

    for epoch in range(num_epochs):
        optimizer = torch.optim.Adam(model.parameters(), lr=curr_lr)  # 保持 Adam 优化器
        train_loss, train_correct = 0.0, 0
        for i, (images, labels) in enumerate(train_loader):
            images = images.to(device)
            labels = labels.to(device)

            # Forward pass
            outputs = model(images)
            loss = criterion(outputs, labels)

            # Backward and optimize
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            train_loss += loss.item() * images.size(0)
            scores, predictions = torch.max(outputs.data, 1)
            train_correct += (predictions == labels).sum().item()

        # Decay learning rate
        if (epoch + 1) % 20 == 0:
            curr_lr /= 3
            update_lr(optimizer, curr_lr)

        valid_loss, valid_correct = 0.0, 0
        model.eval()
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            valid_loss += loss.item() * images.size(0)
            scores, predictions = torch.max(outputs.data, 1)
            valid_correct += (predictions == labels).sum().item()
        ##不好的trial剪枝    
        if trial.should_prune():
            raise optuna.exceptions.TrialPruned()

        train_loss = train_loss / len(train_loader.sampler)
        train_acc = train_correct / len(train_loader.sampler) * 100
        valid_loss = valid_loss / len(test_loader.sampler)
        valid_acc = valid_correct / len(test_loader.sampler) * 100

        print("Epoch:{}/{} \t Train Loss:{:.4f} Valid Loss:{:.4f} \t Train Acc:{:.2f} %  Valid Acc:{:.2f} %".format(
            epoch + 1, num_epochs,
            train_loss,
            valid_loss,
            train_acc,
            valid_acc))
        # history['train_loss'].append(train_loss)
        # history['valid_loss'].append(valid_loss)
        # history['train_acc'].append(train_acc)
        # history['valid_acc'].append(valid_acc)

    return valid_acc


study = optuna.create_study(direction='maximize')

# 运行优化过程
study.optimize(objective, n_trials=20)

# 打印最佳参数和目标值
print('Best trial:')
print('  Value: ', study.best_trial.value)
print('  Params: ')
for key, value in study.best_trial.params.items():
    print('    {}: {}'.format(key, value))
# Out:
# Files already downloaded and verified
# [I 2024-09-28 12:44:40,995] A new study created in memory with name: no-name-ae612396-5282-4c48-b5a4-9e8ab03ff34c
# Epoch:1/100 	 Train Loss:1.6233 Valid Loss:1.5446 	 Train Acc:39.21 %  Valid Acc:44.24 %
# Epoch:2/100 	 Train Loss:1.3166 Valid Loss:1.1979 	 Train Acc:52.14 %  Valid Acc:56.19 %
# Epoch:3/100 	 Train Loss:1.0967 Valid Loss:1.0336 	 Train Acc:60.48 %  Valid Acc:63.10 %
# Epoch:4/100 	 Train Loss:0.9702 Valid Loss:0.9455 	 Train Acc:65.30 %  Valid Acc:67.17 %
# Epoch:5/100 	 Train Loss:0.8643 Valid Loss:0.8286 	 Train Acc:69.36 %  Valid Acc:70.67 %
# Epoch:6/100 	 Train Loss:0.7836 Valid Loss:0.8301 	 Train Acc:72.43 %  Valid Acc:72.14 %
# Epoch:7/100 	 Train Loss:0.7234 Valid Loss:0.7238 	 Train Acc:74.60 %  Valid Acc:75.41 %
# Epoch:8/100 	 Train Loss:0.6686 Valid Loss:0.6882 	 Train Acc:76.65 %  Valid Acc:77.03 %
# Epoch:9/100 	 Train Loss:0.6258 Valid Loss:0.6380 	 Train Acc:78.04 %  Valid Acc:78.82 %
# Epoch:10/100 	 Train Loss:0.5880 Valid Loss:0.6220 	 Train Acc:79.57 %  Valid Acc:78.87 %
# Epoch:11/100 	 Train Loss:0.5654 Valid Loss:0.5881 	 Train Acc:80.25 %  Valid Acc:80.33 %
# Epoch:12/100 	 Train Loss:0.5413 Valid Loss:0.5943 	 Train Acc:81.19 %  Valid Acc:79.97 %
# Epoch:13/100 	 Train Loss:0.5092 Valid Loss:0.5548 	 Train Acc:82.18 %  Valid Acc:81.42 %
# Epoch:14/100 	 Train Loss:0.4941 Valid Loss:0.5233 	 Train Acc:82.86 %  Valid Acc:82.68 %
# Epoch:15/100 	 Train Loss:0.4782 Valid Loss:0.5760 	 Train Acc:83.46 %  Valid Acc:81.32 %
# Epoch:16/100 	 Train Loss:0.4632 Valid Loss:0.5163 	 Train Acc:83.78 %  Valid Acc:83.06 %
# Epoch:17/100 	 Train Loss:0.4494 Valid Loss:0.5426 	 Train Acc:84.18 %  Valid Acc:81.47 %
# Epoch:18/100 	 Train Loss:0.4330 Valid Loss:0.5520 	 Train Acc:84.96 %  Valid Acc:82.06 %
# Epoch:19/100 	 Train Loss:0.4191 Valid Loss:0.4856 	 Train Acc:85.29 %  Valid Acc:84.11 %
# Epoch:20/100 	 Train Loss:0.4050 Valid Loss:0.5088 	 Train Acc:85.80 %  Valid Acc:83.41 %
# Epoch:21/100 	 Train Loss:0.3326 Valid Loss:0.4358 	 Train Acc:88.41 %  Valid Acc:85.77 %
# Epoch:22/100 	 Train Loss:0.3160 Valid Loss:0.4345 	 Train Acc:89.05 %  Valid Acc:86.07 %
# Epoch:23/100 	 Train Loss:0.3077 Valid Loss:0.4396 	 Train Acc:89.10 %  Valid Acc:86.03 %
# Epoch:24/100 	 Train Loss:0.2962 Valid Loss:0.4319 	 Train Acc:89.55 %  Valid Acc:86.22 %
# Epoch:25/100 	 Train Loss:0.2889 Valid Loss:0.4408 	 Train Acc:89.79 %  Valid Acc:85.75 %
# Epoch:26/100 	 Train Loss:0.2865 Valid Loss:0.4500 	 Train Acc:89.99 %  Valid Acc:85.92 %
# Epoch:27/100 	 Train Loss:0.2871 Valid Loss:0.4519 	 Train Acc:89.86 %  Valid Acc:85.88 %
# Epoch:28/100 	 Train Loss:0.2780 Valid Loss:0.4382 	 Train Acc:90.08 %  Valid Acc:86.42 %
# Epoch:29/100 	 Train Loss:0.2740 Valid Loss:0.4309 	 Train Acc:90.35 %  Valid Acc:86.31 %
# Epoch:30/100 	 Train Loss:0.2687 Valid Loss:0.4601 	 Train Acc:90.63 %  Valid Acc:85.82 %
# Epoch:31/100 	 Train Loss:0.2653 Valid Loss:0.4358 	 Train Acc:90.64 %  Valid Acc:86.44 %
# Epoch:32/100 	 Train Loss:0.2601 Valid Loss:0.4304 	 Train Acc:90.84 %  Valid Acc:86.81 %
# Epoch:33/100 	 Train Loss:0.2554 Valid Loss:0.4374 	 Train Acc:91.03 %  Valid Acc:86.31 %
# Epoch:34/100 	 Train Loss:0.2555 Valid Loss:0.4457 	 Train Acc:90.95 %  Valid Acc:85.87 %
# Epoch:35/100 	 Train Loss:0.2494 Valid Loss:0.4518 	 Train Acc:91.27 %  Valid Acc:85.66 %
# Epoch:36/100 	 Train Loss:0.2462 Valid Loss:0.4371 	 Train Acc:91.38 %  Valid Acc:86.51 %
# Epoch:37/100 	 Train Loss:0.2444 Valid Loss:0.4456 	 Train Acc:91.38 %  Valid Acc:86.51 %
# Epoch:38/100 	 Train Loss:0.2376 Valid Loss:0.4738 	 Train Acc:91.52 %  Valid Acc:85.72 %
# Epoch:39/100 	 Train Loss:0.2369 Valid Loss:0.4493 	 Train Acc:91.61 %  Valid Acc:86.41 %
# Epoch:40/100 	 Train Loss:0.2327 Valid Loss:0.4511 	 Train Acc:91.80 %  Valid Acc:86.26 %
# Epoch:41/100 	 Train Loss:0.2030 Valid Loss:0.4349 	 Train Acc:92.91 %  Valid Acc:87.21 %
# Epoch:42/100 	 Train Loss:0.1985 Valid Loss:0.4327 	 Train Acc:93.01 %  Valid Acc:87.06 %
# Epoch:43/100 	 Train Loss:0.1971 Valid Loss:0.4308 	 Train Acc:93.08 %  Valid Acc:87.06 %
# Epoch:44/100 	 Train Loss:0.1943 Valid Loss:0.4342 	 Train Acc:93.23 %  Valid Acc:87.16 %
# Epoch:45/100 	 Train Loss:0.1886 Valid Loss:0.4362 	 Train Acc:93.28 %  Valid Acc:87.01 %
# Epoch:46/100 	 Train Loss:0.1898 Valid Loss:0.4476 	 Train Acc:93.23 %  Valid Acc:87.01 %
# Epoch:47/100 	 Train Loss:0.1881 Valid Loss:0.4365 	 Train Acc:93.26 %  Valid Acc:87.22 %
# Epoch:48/100 	 Train Loss:0.1870 Valid Loss:0.4445 	 Train Acc:93.44 %  Valid Acc:87.25 %
# Epoch:49/100 	 Train Loss:0.1860 Valid Loss:0.4386 	 Train Acc:93.41 %  Valid Acc:86.93 %
# Epoch:50/100 	 Train Loss:0.1826 Valid Loss:0.4407 	 Train Acc:93.45 %  Valid Acc:87.15 %
# Epoch:51/100 	 Train Loss:0.1806 Valid Loss:0.4407 	 Train Acc:93.56 %  Valid Acc:87.25 %
# Epoch:52/100 	 Train Loss:0.1798 Valid Loss:0.4523 	 Train Acc:93.59 %  Valid Acc:87.28 %
# Epoch:53/100 	 Train Loss:0.1785 Valid Loss:0.4505 	 Train Acc:93.58 %  Valid Acc:86.91 %
# Epoch:54/100 	 Train Loss:0.1760 Valid Loss:0.4517 	 Train Acc:93.82 %  Valid Acc:87.04 %
# Epoch:55/100 	 Train Loss:0.1745 Valid Loss:0.4429 	 Train Acc:93.87 %  Valid Acc:87.20 %
# Epoch:56/100 	 Train Loss:0.1769 Valid Loss:0.4527 	 Train Acc:93.70 %  Valid Acc:87.05 %
# Epoch:57/100 	 Train Loss:0.1733 Valid Loss:0.4472 	 Train Acc:93.83 %  Valid Acc:87.04 %
# Epoch:58/100 	 Train Loss:0.1737 Valid Loss:0.4467 	 Train Acc:93.85 %  Valid Acc:87.35 %
# Epoch:59/100 	 Train Loss:0.1716 Valid Loss:0.4534 	 Train Acc:93.95 %  Valid Acc:87.16 %
# Epoch:60/100 	 Train Loss:0.1693 Valid Loss:0.4580 	 Train Acc:94.04 %  Valid Acc:86.94 %
# Epoch:61/100 	 Train Loss:0.1596 Valid Loss:0.4498 	 Train Acc:94.32 %  Valid Acc:87.18 %
# Epoch:62/100 	 Train Loss:0.1578 Valid Loss:0.4549 	 Train Acc:94.42 %  Valid Acc:87.21 %
# Epoch:63/100 	 Train Loss:0.1547 Valid Loss:0.4582 	 Train Acc:94.51 %  Valid Acc:87.29 %
# Epoch:64/100 	 Train Loss:0.1587 Valid Loss:0.4522 	 Train Acc:94.35 %  Valid Acc:87.21 %
# Epoch:65/100 	 Train Loss:0.1539 Valid Loss:0.4547 	 Train Acc:94.62 %  Valid Acc:87.54 %
# Epoch:66/100 	 Train Loss:0.1547 Valid Loss:0.4518 	 Train Acc:94.49 %  Valid Acc:87.25 %
# Epoch:67/100 	 Train Loss:0.1554 Valid Loss:0.4559 	 Train Acc:94.59 %  Valid Acc:87.39 %
# Epoch:68/100 	 Train Loss:0.1550 Valid Loss:0.4595 	 Train Acc:94.44 %  Valid Acc:87.20 %
# Epoch:69/100 	 Train Loss:0.1527 Valid Loss:0.4573 	 Train Acc:94.60 %  Valid Acc:87.21 %
# Epoch:70/100 	 Train Loss:0.1516 Valid Loss:0.4622 	 Train Acc:94.58 %  Valid Acc:87.23 %
# Epoch:71/100 	 Train Loss:0.1538 Valid Loss:0.4607 	 Train Acc:94.65 %  Valid Acc:87.30 %
# Epoch:72/100 	 Train Loss:0.1494 Valid Loss:0.4609 	 Train Acc:94.78 %  Valid Acc:87.20 %
# Epoch:73/100 	 Train Loss:0.1532 Valid Loss:0.4612 	 Train Acc:94.46 %  Valid Acc:87.35 %
# Epoch:74/100 	 Train Loss:0.1505 Valid Loss:0.4635 	 Train Acc:94.65 %  Valid Acc:87.16 %
# Epoch:75/100 	 Train Loss:0.1481 Valid Loss:0.4659 	 Train Acc:94.71 %  Valid Acc:87.19 %
# Epoch:76/100 	 Train Loss:0.1504 Valid Loss:0.4652 	 Train Acc:94.74 %  Valid Acc:87.27 %
# Epoch:77/100 	 Train Loss:0.1483 Valid Loss:0.4658 	 Train Acc:94.82 %  Valid Acc:87.33 %
# Epoch:78/100 	 Train Loss:0.1494 Valid Loss:0.4630 	 Train Acc:94.73 %  Valid Acc:87.31 %
# Epoch:79/100 	 Train Loss:0.1505 Valid Loss:0.4688 	 Train Acc:94.68 %  Valid Acc:87.17 %
# Epoch:80/100 	 Train Loss:0.1478 Valid Loss:0.4674 	 Train Acc:94.68 %  Valid Acc:87.28 %
# Epoch:81/100 	 Train Loss:0.1476 Valid Loss:0.4645 	 Train Acc:94.66 %  Valid Acc:87.52 %
# Epoch:82/100 	 Train Loss:0.1422 Valid Loss:0.4658 	 Train Acc:94.94 %  Valid Acc:87.41 %
# Epoch:83/100 	 Train Loss:0.1424 Valid Loss:0.4660 	 Train Acc:94.91 %  Valid Acc:87.35 %
# Epoch:84/100 	 Train Loss:0.1461 Valid Loss:0.4638 	 Train Acc:94.87 %  Valid Acc:87.33 %
# Epoch:85/100 	 Train Loss:0.1424 Valid Loss:0.4639 	 Train Acc:94.95 %  Valid Acc:87.38 %
# Epoch:86/100 	 Train Loss:0.1444 Valid Loss:0.4648 	 Train Acc:94.94 %  Valid Acc:87.46 %
# Epoch:87/100 	 Train Loss:0.1454 Valid Loss:0.4657 	 Train Acc:94.77 %  Valid Acc:87.47 %
# Epoch:88/100 	 Train Loss:0.1421 Valid Loss:0.4658 	 Train Acc:94.93 %  Valid Acc:87.41 %
# Epoch:89/100 	 Train Loss:0.1411 Valid Loss:0.4652 	 Train Acc:94.99 %  Valid Acc:87.45 %
# Epoch:90/100 	 Train Loss:0.1427 Valid Loss:0.4655 	 Train Acc:94.96 %  Valid Acc:87.45 %
# Epoch:91/100 	 Train Loss:0.1418 Valid Loss:0.4676 	 Train Acc:94.92 %  Valid Acc:87.50 %
# Epoch:92/100 	 Train Loss:0.1421 Valid Loss:0.4674 	 Train Acc:95.07 %  Valid Acc:87.38 %
# Epoch:93/100 	 Train Loss:0.1401 Valid Loss:0.4673 	 Train Acc:95.03 %  Valid Acc:87.39 %
# Epoch:94/100 	 Train Loss:0.1385 Valid Loss:0.4667 	 Train Acc:95.15 %  Valid Acc:87.56 %
# Epoch:95/100 	 Train Loss:0.1403 Valid Loss:0.4697 	 Train Acc:94.91 %  Valid Acc:87.48 %
# Epoch:96/100 	 Train Loss:0.1412 Valid Loss:0.4696 	 Train Acc:95.04 %  Valid Acc:87.33 %
# Epoch:97/100 	 Train Loss:0.1418 Valid Loss:0.4687 	 Train Acc:94.84 %  Valid Acc:87.30 %
# Epoch:98/100 	 Train Loss:0.1402 Valid Loss:0.4685 	 Train Acc:95.01 %  Valid Acc:87.56 %
# Epoch:99/100 	 Train Loss:0.1415 Valid Loss:0.4695 	 Train Acc:94.95 %  Valid Acc:87.38 %
# [I 2024-09-28 14:00:18,962] Trial 0 finished with value: 87.46000000000001 and parameters: {'sigma_1': 4.117417817946505, 'sigma_2': 5.449013271348036, 'sigma_3': 2.779244364432301, 'sigma_4': 4.530349575211693, 'sigma_5': 5.967907012091073, 'sigma_6': 4.889869277518576, 'sigma_7': 5.773191060313531, 'sigma_8': 3.1520967075023574, 'sigma_9': 5.906979297861794, 'sigma_10': 2.588424490048343, 'sigma_11': 5.008784183170302, 'sigma_12': 4.927360753952874, 'sigma_13': 4.507570565685883}. Best is trial 0 with value: 87.46000000000001.
# Epoch:100/100 	 Train Loss:0.1398 Valid Loss:0.4682 	 Train Acc:95.07 %  Valid Acc:87.46 %
# Epoch:1/100 	 Train Loss:1.5555 Valid Loss:1.6297 	 Train Acc:42.54 %  Valid Acc:43.64 %
# Epoch:2/100 	 Train Loss:1.2029 Valid Loss:1.1941 	 Train Acc:56.68 %  Valid Acc:58.49 %
# Epoch:3/100 	 Train Loss:1.0201 Valid Loss:0.9900 	 Train Acc:63.65 %  Valid Acc:65.04 %
# Epoch:4/100 	 Train Loss:0.9026 Valid Loss:0.8388 	 Train Acc:67.97 %  Valid Acc:70.24 %
# Epoch:5/100 	 Train Loss:0.8066 Valid Loss:0.7790 	 Train Acc:71.49 %  Valid Acc:72.79 %
# Epoch:6/100 	 Train Loss:0.7353 Valid Loss:0.7249 	 Train Acc:74.26 %  Valid Acc:74.81 %
# Epoch:7/100 	 Train Loss:0.6851 Valid Loss:0.6999 	 Train Acc:75.83 %  Valid Acc:75.68 %
# Epoch:8/100 	 Train Loss:0.6469 Valid Loss:0.6991 	 Train Acc:77.45 %  Valid Acc:76.06 %
# Epoch:9/100 	 Train Loss:0.6116 Valid Loss:0.6528 	 Train Acc:78.58 %  Valid Acc:77.67 %
# Epoch:10/100 	 Train Loss:0.5859 Valid Loss:0.6265 	 Train Acc:79.60 %  Valid Acc:78.64 %
# Epoch:11/100 	 Train Loss:0.5591 Valid Loss:0.6272 	 Train Acc:80.38 %  Valid Acc:79.27 %
# Epoch:12/100 	 Train Loss:0.5303 Valid Loss:0.5973 	 Train Acc:81.64 %  Valid Acc:79.53 %
# Epoch:13/100 	 Train Loss:0.5166 Valid Loss:0.5684 	 Train Acc:81.96 %  Valid Acc:81.01 %
# Epoch:14/100 	 Train Loss:0.4941 Valid Loss:0.5815 	 Train Acc:82.96 %  Valid Acc:81.02 %
# Epoch:15/100 	 Train Loss:0.4861 Valid Loss:0.5456 	 Train Acc:83.04 %  Valid Acc:81.30 %
# Epoch:16/100 	 Train Loss:0.4716 Valid Loss:0.5144 	 Train Acc:83.61 %  Valid Acc:82.96 %
# Epoch:17/100 	 Train Loss:0.4616 Valid Loss:0.5350 	 Train Acc:84.02 %  Valid Acc:82.04 %
# Epoch:18/100 	 Train Loss:0.4446 Valid Loss:0.5160 	 Train Acc:84.47 %  Valid Acc:83.01 %
# Epoch:19/100 	 Train Loss:0.4384 Valid Loss:0.5399 	 Train Acc:84.71 %  Valid Acc:82.07 %
# Epoch:20/100 	 Train Loss:0.4244 Valid Loss:0.5308 	 Train Acc:85.27 %  Valid Acc:82.48 %
# Epoch:21/100 	 Train Loss:0.3470 Valid Loss:0.4716 	 Train Acc:88.03 %  Valid Acc:84.73 %
# Epoch:22/100 	 Train Loss:0.3283 Valid Loss:0.4734 	 Train Acc:88.44 %  Valid Acc:85.10 %
# Epoch:23/100 	 Train Loss:0.3241 Valid Loss:0.4671 	 Train Acc:88.79 %  Valid Acc:85.17 %
# Epoch:24/100 	 Train Loss:0.3170 Valid Loss:0.4570 	 Train Acc:88.90 %  Valid Acc:85.36 %
# Epoch:25/100 	 Train Loss:0.3120 Valid Loss:0.4636 	 Train Acc:89.09 %  Valid Acc:85.40 %
# Epoch:26/100 	 Train Loss:0.3025 Valid Loss:0.4613 	 Train Acc:89.37 %  Valid Acc:85.43 %
# Epoch:27/100 	 Train Loss:0.2974 Valid Loss:0.4615 	 Train Acc:89.46 %  Valid Acc:85.70 %
# Epoch:28/100 	 Train Loss:0.2939 Valid Loss:0.4658 	 Train Acc:89.76 %  Valid Acc:85.77 %
# Epoch:29/100 	 Train Loss:0.2923 Valid Loss:0.4857 	 Train Acc:89.77 %  Valid Acc:84.85 %
# Epoch:30/100 	 Train Loss:0.2876 Valid Loss:0.4797 	 Train Acc:89.95 %  Valid Acc:85.34 %
# Epoch:31/100 	 Train Loss:0.2857 Valid Loss:0.4854 	 Train Acc:89.97 %  Valid Acc:85.21 %
# Epoch:32/100 	 Train Loss:0.2825 Valid Loss:0.4585 	 Train Acc:90.13 %  Valid Acc:85.87 %
# Epoch:33/100 	 Train Loss:0.2745 Valid Loss:0.4694 	 Train Acc:90.23 %  Valid Acc:85.43 %
# Epoch:34/100 	 Train Loss:0.2729 Valid Loss:0.4634 	 Train Acc:90.34 %  Valid Acc:85.86 %
# Epoch:35/100 	 Train Loss:0.2713 Valid Loss:0.4936 	 Train Acc:90.46 %  Valid Acc:85.08 %
# Epoch:36/100 	 Train Loss:0.2668 Valid Loss:0.4480 	 Train Acc:90.59 %  Valid Acc:86.09 %
# Epoch:37/100 	 Train Loss:0.2625 Valid Loss:0.4768 	 Train Acc:90.70 %  Valid Acc:85.81 %
# Epoch:38/100 	 Train Loss:0.2584 Valid Loss:0.4683 	 Train Acc:90.90 %  Valid Acc:85.96 %
# Epoch:39/100 	 Train Loss:0.2552 Valid Loss:0.4754 	 Train Acc:90.97 %  Valid Acc:85.55 %
# Epoch:40/100 	 Train Loss:0.2542 Valid Loss:0.4774 	 Train Acc:91.02 %  Valid Acc:86.03 %
# Epoch:41/100 	 Train Loss:0.2276 Valid Loss:0.4611 	 Train Acc:92.03 %  Valid Acc:86.35 %
# Epoch:42/100 	 Train Loss:0.2203 Valid Loss:0.4597 	 Train Acc:92.14 %  Valid Acc:86.53 %
# Epoch:43/100 	 Train Loss:0.2153 Valid Loss:0.4660 	 Train Acc:92.47 %  Valid Acc:86.25 %
# Epoch:44/100 	 Train Loss:0.2142 Valid Loss:0.4584 	 Train Acc:92.44 %  Valid Acc:86.39 %
# Epoch:45/100 	 Train Loss:0.2119 Valid Loss:0.4700 	 Train Acc:92.41 %  Valid Acc:86.26 %
# Epoch:46/100 	 Train Loss:0.2107 Valid Loss:0.4757 	 Train Acc:92.49 %  Valid Acc:86.50 %
# Epoch:47/100 	 Train Loss:0.2082 Valid Loss:0.4719 	 Train Acc:92.64 %  Valid Acc:86.45 %
# Epoch:48/100 	 Train Loss:0.2110 Valid Loss:0.4677 	 Train Acc:92.57 %  Valid Acc:86.45 %
# Epoch:49/100 	 Train Loss:0.2082 Valid Loss:0.4715 	 Train Acc:92.66 %  Valid Acc:86.33 %
# Epoch:50/100 	 Train Loss:0.2047 Valid Loss:0.4747 	 Train Acc:92.77 %  Valid Acc:86.43 %
# Epoch:51/100 	 Train Loss:0.2032 Valid Loss:0.4659 	 Train Acc:92.94 %  Valid Acc:86.43 %
# Epoch:52/100 	 Train Loss:0.2056 Valid Loss:0.4699 	 Train Acc:92.69 %  Valid Acc:86.28 %
# Epoch:53/100 	 Train Loss:0.2012 Valid Loss:0.4735 	 Train Acc:92.87 %  Valid Acc:86.49 %
# Epoch:54/100 	 Train Loss:0.1990 Valid Loss:0.4771 	 Train Acc:92.78 %  Valid Acc:86.40 %
# Epoch:55/100 	 Train Loss:0.1991 Valid Loss:0.4745 	 Train Acc:92.98 %  Valid Acc:86.53 %
# Epoch:56/100 	 Train Loss:0.1948 Valid Loss:0.4711 	 Train Acc:93.14 %  Valid Acc:86.37 %
# Epoch:57/100 	 Train Loss:0.1980 Valid Loss:0.4762 	 Train Acc:92.99 %  Valid Acc:86.56 %
# Epoch:58/100 	 Train Loss:0.1948 Valid Loss:0.4742 	 Train Acc:93.10 %  Valid Acc:86.69 %
# Epoch:59/100 	 Train Loss:0.1933 Valid Loss:0.4902 	 Train Acc:93.16 %  Valid Acc:86.44 %
# Epoch:60/100 	 Train Loss:0.1941 Valid Loss:0.4797 	 Train Acc:92.95 %  Valid Acc:86.47 %
# Epoch:61/100 	 Train Loss:0.1824 Valid Loss:0.4753 	 Train Acc:93.53 %  Valid Acc:86.64 %
# Epoch:62/100 	 Train Loss:0.1826 Valid Loss:0.4803 	 Train Acc:93.49 %  Valid Acc:86.56 %
# Epoch:63/100 	 Train Loss:0.1792 Valid Loss:0.4782 	 Train Acc:93.68 %  Valid Acc:86.71 %
# Epoch:64/100 	 Train Loss:0.1784 Valid Loss:0.4764 	 Train Acc:93.61 %  Valid Acc:86.61 %
# Epoch:65/100 	 Train Loss:0.1775 Valid Loss:0.4825 	 Train Acc:93.65 %  Valid Acc:86.60 %
# Epoch:66/100 	 Train Loss:0.1777 Valid Loss:0.4814 	 Train Acc:93.70 %  Valid Acc:86.75 %
# Epoch:67/100 	 Train Loss:0.1791 Valid Loss:0.4819 	 Train Acc:93.69 %  Valid Acc:86.88 %
# Epoch:68/100 	 Train Loss:0.1771 Valid Loss:0.4816 	 Train Acc:93.72 %  Valid Acc:86.75 %
# Epoch:69/100 	 Train Loss:0.1758 Valid Loss:0.4831 	 Train Acc:93.73 %  Valid Acc:86.73 %
# Epoch:70/100 	 Train Loss:0.1746 Valid Loss:0.4844 	 Train Acc:93.87 %  Valid Acc:86.83 %
# Epoch:71/100 	 Train Loss:0.1742 Valid Loss:0.4854 	 Train Acc:93.81 %  Valid Acc:86.79 %
# Epoch:72/100 	 Train Loss:0.1779 Valid Loss:0.4852 	 Train Acc:93.64 %  Valid Acc:86.73 %
# Epoch:73/100 	 Train Loss:0.1752 Valid Loss:0.4842 	 Train Acc:93.73 %  Valid Acc:86.82 %
# Epoch:74/100 	 Train Loss:0.1713 Valid Loss:0.4880 	 Train Acc:93.82 %  Valid Acc:86.75 %
# Epoch:75/100 	 Train Loss:0.1720 Valid Loss:0.4906 	 Train Acc:93.89 %  Valid Acc:86.74 %
# Epoch:76/100 	 Train Loss:0.1712 Valid Loss:0.4890 	 Train Acc:93.92 %  Valid Acc:86.83 %
# Epoch:77/100 	 Train Loss:0.1709 Valid Loss:0.4839 	 Train Acc:93.98 %  Valid Acc:86.81 %
# Epoch:78/100 	 Train Loss:0.1741 Valid Loss:0.4872 	 Train Acc:93.87 %  Valid Acc:86.74 %
# Epoch:79/100 	 Train Loss:0.1730 Valid Loss:0.4890 	 Train Acc:93.86 %  Valid Acc:86.76 %
# Epoch:80/100 	 Train Loss:0.1734 Valid Loss:0.4834 	 Train Acc:93.80 %  Valid Acc:86.79 %
# Epoch:81/100 	 Train Loss:0.1681 Valid Loss:0.4871 	 Train Acc:94.09 %  Valid Acc:86.78 %
# Epoch:82/100 	 Train Loss:0.1649 Valid Loss:0.4882 	 Train Acc:94.17 %  Valid Acc:86.84 %
# Epoch:83/100 	 Train Loss:0.1685 Valid Loss:0.4887 	 Train Acc:94.00 %  Valid Acc:86.93 %
# Epoch:84/100 	 Train Loss:0.1642 Valid Loss:0.4902 	 Train Acc:94.27 %  Valid Acc:86.82 %
# Epoch:85/100 	 Train Loss:0.1664 Valid Loss:0.4896 	 Train Acc:94.07 %  Valid Acc:86.84 %
# Epoch:86/100 	 Train Loss:0.1655 Valid Loss:0.4928 	 Train Acc:94.25 %  Valid Acc:86.84 %
# Epoch:87/100 	 Train Loss:0.1680 Valid Loss:0.4913 	 Train Acc:94.00 %  Valid Acc:86.80 %
# Epoch:88/100 	 Train Loss:0.1664 Valid Loss:0.4894 	 Train Acc:94.06 %  Valid Acc:86.80 %
# Epoch:89/100 	 Train Loss:0.1647 Valid Loss:0.4899 	 Train Acc:94.10 %  Valid Acc:86.72 %
# Epoch:90/100 	 Train Loss:0.1655 Valid Loss:0.4931 	 Train Acc:94.23 %  Valid Acc:86.81 %
# Epoch:91/100 	 Train Loss:0.1647 Valid Loss:0.4926 	 Train Acc:94.15 %  Valid Acc:86.81 %
# Epoch:92/100 	 Train Loss:0.1680 Valid Loss:0.4913 	 Train Acc:94.14 %  Valid Acc:86.81 %
# Epoch:93/100 	 Train Loss:0.1646 Valid Loss:0.4924 	 Train Acc:94.27 %  Valid Acc:86.80 %
# Epoch:94/100 	 Train Loss:0.1649 Valid Loss:0.4926 	 Train Acc:94.25 %  Valid Acc:86.82 %
# Epoch:95/100 	 Train Loss:0.1640 Valid Loss:0.4927 	 Train Acc:94.26 %  Valid Acc:86.72 %
# Epoch:96/100 	 Train Loss:0.1632 Valid Loss:0.4899 	 Train Acc:94.33 %  Valid Acc:86.86 %
# Epoch:97/100 	 Train Loss:0.1619 Valid Loss:0.4922 	 Train Acc:94.24 %  Valid Acc:86.76 %
# Epoch:98/100 	 Train Loss:0.1653 Valid Loss:0.4914 	 Train Acc:94.23 %  Valid Acc:86.95 %
# Epoch:99/100 	 Train Loss:0.1641 Valid Loss:0.4924 	 Train Acc:94.32 %  Valid Acc:86.86 %
# [I 2024-09-28 15:15:54,785] Trial 1 finished with value: 86.88 and parameters: {'sigma_1': 3.956572633440479, 'sigma_2': 5.818852403655713, 'sigma_3': 5.04592344670842, 'sigma_4': 4.049405329095023, 'sigma_5': 5.236927212380223, 'sigma_6': 3.01469295361493, 'sigma_7': 2.6576120661687086, 'sigma_8': 2.6925896709777346, 'sigma_9': 4.942355931055474, 'sigma_10': 4.882624463432087, 'sigma_11': 3.525408800152578, 'sigma_12': 2.6858769675508247, 'sigma_13': 2.2575777656768525}. Best is trial 0 with value: 87.46000000000001.
# Epoch:100/100 	 Train Loss:0.1640 Valid Loss:0.4924 	 Train Acc:94.26 %  Valid Acc:86.88 %
# Epoch:1/100 	 Train Loss:1.5626 Valid Loss:1.3686 	 Train Acc:41.90 %  Valid Acc:50.31 %
# Epoch:2/100 	 Train Loss:1.2242 Valid Loss:1.0577 	 Train Acc:55.99 %  Valid Acc:61.52 %
# Epoch:3/100 	 Train Loss:1.0354 Valid Loss:1.0527 	 Train Acc:63.01 %  Valid Acc:63.01 %
# Epoch:4/100 	 Train Loss:0.9129 Valid Loss:0.8740 	 Train Acc:67.46 %  Valid Acc:69.33 %
# Epoch:5/100 	 Train Loss:0.8255 Valid Loss:0.7780 	 Train Acc:70.90 %  Valid Acc:73.27 %
# Epoch:6/100 	 Train Loss:0.7427 Valid Loss:0.7389 	 Train Acc:73.99 %  Valid Acc:73.75 %
# Epoch:7/100 	 Train Loss:0.6924 Valid Loss:0.6743 	 Train Acc:76.01 %  Valid Acc:76.57 %
# Epoch:8/100 	 Train Loss:0.6500 Valid Loss:0.7170 	 Train Acc:77.44 %  Valid Acc:75.00 %
# Epoch:9/100 	 Train Loss:0.6116 Valid Loss:0.6169 	 Train Acc:78.64 %  Valid Acc:79.05 %
# Epoch:10/100 	 Train Loss:0.5874 Valid Loss:0.5925 	 Train Acc:79.49 %  Valid Acc:80.46 %
# Epoch:11/100 	 Train Loss:0.5554 Valid Loss:0.6082 	 Train Acc:80.69 %  Valid Acc:79.32 %
# Epoch:12/100 	 Train Loss:0.5378 Valid Loss:0.5995 	 Train Acc:81.36 %  Valid Acc:79.69 %
# Epoch:13/100 	 Train Loss:0.5151 Valid Loss:0.5896 	 Train Acc:81.99 %  Valid Acc:79.84 %
# Epoch:14/100 	 Train Loss:0.4982 Valid Loss:0.5789 	 Train Acc:82.68 %  Valid Acc:80.82 %
# Epoch:15/100 	 Train Loss:0.4890 Valid Loss:0.5520 	 Train Acc:82.99 %  Valid Acc:80.89 %
# Epoch:16/100 	 Train Loss:0.4683 Valid Loss:0.5687 	 Train Acc:83.63 %  Valid Acc:80.92 %
# Epoch:17/100 	 Train Loss:0.4553 Valid Loss:0.5286 	 Train Acc:84.06 %  Valid Acc:82.76 %
# Epoch:18/100 	 Train Loss:0.4403 Valid Loss:0.5242 	 Train Acc:84.74 %  Valid Acc:82.76 %
# Epoch:19/100 	 Train Loss:0.4298 Valid Loss:0.5789 	 Train Acc:85.16 %  Valid Acc:80.96 %
# Epoch:20/100 	 Train Loss:0.4235 Valid Loss:0.5062 	 Train Acc:85.42 %  Valid Acc:83.23 %
# Epoch:21/100 	 Train Loss:0.3447 Valid Loss:0.4679 	 Train Acc:88.11 %  Valid Acc:84.53 %
# Epoch:22/100 	 Train Loss:0.3281 Valid Loss:0.4587 	 Train Acc:88.57 %  Valid Acc:85.53 %
# Epoch:23/100 	 Train Loss:0.3212 Valid Loss:0.4672 	 Train Acc:88.82 %  Valid Acc:85.15 %
# Epoch:24/100 	 Train Loss:0.3108 Valid Loss:0.4568 	 Train Acc:89.15 %  Valid Acc:85.22 %
# Epoch:25/100 	 Train Loss:0.3027 Valid Loss:0.4483 	 Train Acc:89.42 %  Valid Acc:85.83 %
# Epoch:26/100 	 Train Loss:0.3000 Valid Loss:0.4577 	 Train Acc:89.64 %  Valid Acc:85.04 %
# Epoch:27/100 	 Train Loss:0.2952 Valid Loss:0.4425 	 Train Acc:89.53 %  Valid Acc:85.84 %
# Epoch:28/100 	 Train Loss:0.2855 Valid Loss:0.4479 	 Train Acc:89.98 %  Valid Acc:85.69 %
# Epoch:29/100 	 Train Loss:0.2873 Valid Loss:0.4576 	 Train Acc:89.99 %  Valid Acc:85.54 %
# Epoch:30/100 	 Train Loss:0.2800 Valid Loss:0.4507 	 Train Acc:90.13 %  Valid Acc:85.91 %
# Epoch:31/100 	 Train Loss:0.2753 Valid Loss:0.4599 	 Train Acc:90.35 %  Valid Acc:85.38 %
# Epoch:32/100 	 Train Loss:0.2727 Valid Loss:0.4685 	 Train Acc:90.32 %  Valid Acc:85.32 %
# Epoch:33/100 	 Train Loss:0.2710 Valid Loss:0.4557 	 Train Acc:90.43 %  Valid Acc:85.52 %
# Epoch:34/100 	 Train Loss:0.2656 Valid Loss:0.4839 	 Train Acc:90.63 %  Valid Acc:85.12 %
# Epoch:35/100 	 Train Loss:0.2632 Valid Loss:0.4450 	 Train Acc:90.65 %  Valid Acc:86.01 %
# Epoch:36/100 	 Train Loss:0.2624 Valid Loss:0.4521 	 Train Acc:90.72 %  Valid Acc:85.98 %
# Epoch:37/100 	 Train Loss:0.2578 Valid Loss:0.4511 	 Train Acc:90.93 %  Valid Acc:86.27 %
# Epoch:38/100 	 Train Loss:0.2555 Valid Loss:0.4612 	 Train Acc:90.85 %  Valid Acc:86.07 %
# Epoch:39/100 	 Train Loss:0.2514 Valid Loss:0.4501 	 Train Acc:91.07 %  Valid Acc:86.49 %
# Epoch:40/100 	 Train Loss:0.2464 Valid Loss:0.4518 	 Train Acc:91.36 %  Valid Acc:86.01 %
# Epoch:41/100 	 Train Loss:0.2182 Valid Loss:0.4358 	 Train Acc:92.25 %  Valid Acc:86.93 %
# Epoch:42/100 	 Train Loss:0.2136 Valid Loss:0.4399 	 Train Acc:92.58 %  Valid Acc:86.59 %
# Epoch:43/100 	 Train Loss:0.2085 Valid Loss:0.4488 	 Train Acc:92.67 %  Valid Acc:86.70 %
# Epoch:44/100 	 Train Loss:0.2090 Valid Loss:0.4455 	 Train Acc:92.67 %  Valid Acc:86.88 %
# Epoch:45/100 	 Train Loss:0.2048 Valid Loss:0.4357 	 Train Acc:92.73 %  Valid Acc:87.08 %
# Epoch:46/100 	 Train Loss:0.2039 Valid Loss:0.4463 	 Train Acc:92.85 %  Valid Acc:86.50 %
# Epoch:47/100 	 Train Loss:0.1999 Valid Loss:0.4462 	 Train Acc:92.83 %  Valid Acc:86.78 %
# Epoch:48/100 	 Train Loss:0.1995 Valid Loss:0.4446 	 Train Acc:93.00 %  Valid Acc:86.91 %
# Epoch:49/100 	 Train Loss:0.2008 Valid Loss:0.4446 	 Train Acc:92.87 %  Valid Acc:86.84 %
# Epoch:50/100 	 Train Loss:0.1959 Valid Loss:0.4543 	 Train Acc:93.05 %  Valid Acc:86.96 %
# Epoch:51/100 	 Train Loss:0.1936 Valid Loss:0.4578 	 Train Acc:93.11 %  Valid Acc:86.56 %
# Epoch:52/100 	 Train Loss:0.1946 Valid Loss:0.4616 	 Train Acc:93.07 %  Valid Acc:86.64 %
# Epoch:53/100 	 Train Loss:0.1916 Valid Loss:0.4550 	 Train Acc:93.26 %  Valid Acc:86.91 %
# Epoch:54/100 	 Train Loss:0.1918 Valid Loss:0.4506 	 Train Acc:93.16 %  Valid Acc:86.47 %
# Epoch:55/100 	 Train Loss:0.1898 Valid Loss:0.4591 	 Train Acc:93.28 %  Valid Acc:86.52 %
# Epoch:56/100 	 Train Loss:0.1910 Valid Loss:0.4613 	 Train Acc:93.17 %  Valid Acc:86.64 %
# Epoch:57/100 	 Train Loss:0.1893 Valid Loss:0.4624 	 Train Acc:93.32 %  Valid Acc:86.73 %
# Epoch:58/100 	 Train Loss:0.1886 Valid Loss:0.4577 	 Train Acc:93.29 %  Valid Acc:86.79 %
# Epoch:59/100 	 Train Loss:0.1862 Valid Loss:0.4561 	 Train Acc:93.34 %  Valid Acc:86.78 %
# Epoch:60/100 	 Train Loss:0.1862 Valid Loss:0.4755 	 Train Acc:93.27 %  Valid Acc:86.46 %
# Epoch:61/100 	 Train Loss:0.1748 Valid Loss:0.4600 	 Train Acc:93.77 %  Valid Acc:86.95 %
# Epoch:62/100 	 Train Loss:0.1726 Valid Loss:0.4582 	 Train Acc:93.98 %  Valid Acc:87.00 %
# Epoch:63/100 	 Train Loss:0.1721 Valid Loss:0.4547 	 Train Acc:93.92 %  Valid Acc:87.03 %
# Epoch:64/100 	 Train Loss:0.1731 Valid Loss:0.4594 	 Train Acc:93.90 %  Valid Acc:87.07 %
# Epoch:65/100 	 Train Loss:0.1692 Valid Loss:0.4617 	 Train Acc:93.92 %  Valid Acc:86.95 %
# Epoch:66/100 	 Train Loss:0.1708 Valid Loss:0.4616 	 Train Acc:93.97 %  Valid Acc:87.01 %
# Epoch:67/100 	 Train Loss:0.1686 Valid Loss:0.4640 	 Train Acc:94.07 %  Valid Acc:87.00 %
# Epoch:68/100 	 Train Loss:0.1678 Valid Loss:0.4688 	 Train Acc:94.08 %  Valid Acc:86.90 %
# Epoch:69/100 	 Train Loss:0.1695 Valid Loss:0.4616 	 Train Acc:94.02 %  Valid Acc:87.05 %
# Epoch:70/100 	 Train Loss:0.1674 Valid Loss:0.4636 	 Train Acc:94.06 %  Valid Acc:87.07 %
# Epoch:71/100 	 Train Loss:0.1687 Valid Loss:0.4637 	 Train Acc:94.01 %  Valid Acc:86.94 %
# Epoch:72/100 	 Train Loss:0.1656 Valid Loss:0.4661 	 Train Acc:94.18 %  Valid Acc:87.01 %
# Epoch:73/100 	 Train Loss:0.1655 Valid Loss:0.4664 	 Train Acc:94.11 %  Valid Acc:86.90 %
# Epoch:74/100 	 Train Loss:0.1653 Valid Loss:0.4683 	 Train Acc:94.13 %  Valid Acc:86.85 %
# Epoch:75/100 	 Train Loss:0.1655 Valid Loss:0.4688 	 Train Acc:94.08 %  Valid Acc:86.82 %
# Epoch:76/100 	 Train Loss:0.1652 Valid Loss:0.4697 	 Train Acc:94.20 %  Valid Acc:87.02 %
# Epoch:77/100 	 Train Loss:0.1637 Valid Loss:0.4686 	 Train Acc:94.13 %  Valid Acc:86.88 %
# Epoch:78/100 	 Train Loss:0.1647 Valid Loss:0.4684 	 Train Acc:94.14 %  Valid Acc:86.99 %
# Epoch:79/100 	 Train Loss:0.1650 Valid Loss:0.4739 	 Train Acc:94.12 %  Valid Acc:86.74 %
# Epoch:80/100 	 Train Loss:0.1642 Valid Loss:0.4673 	 Train Acc:94.14 %  Valid Acc:86.74 %
# Epoch:81/100 	 Train Loss:0.1591 Valid Loss:0.4670 	 Train Acc:94.32 %  Valid Acc:86.92 %
# Epoch:82/100 	 Train Loss:0.1603 Valid Loss:0.4670 	 Train Acc:94.36 %  Valid Acc:87.02 %
# Epoch:83/100 	 Train Loss:0.1588 Valid Loss:0.4676 	 Train Acc:94.26 %  Valid Acc:86.94 %
# Epoch:84/100 	 Train Loss:0.1604 Valid Loss:0.4677 	 Train Acc:94.41 %  Valid Acc:86.98 %
# Epoch:85/100 	 Train Loss:0.1549 Valid Loss:0.4693 	 Train Acc:94.47 %  Valid Acc:86.93 %
# Epoch:86/100 	 Train Loss:0.1582 Valid Loss:0.4700 	 Train Acc:94.42 %  Valid Acc:86.89 %
# Epoch:87/100 	 Train Loss:0.1586 Valid Loss:0.4711 	 Train Acc:94.32 %  Valid Acc:86.92 %
# Epoch:88/100 	 Train Loss:0.1573 Valid Loss:0.4695 	 Train Acc:94.54 %  Valid Acc:87.03 %
# Epoch:89/100 	 Train Loss:0.1576 Valid Loss:0.4707 	 Train Acc:94.42 %  Valid Acc:86.93 %
# Epoch:90/100 	 Train Loss:0.1546 Valid Loss:0.4723 	 Train Acc:94.59 %  Valid Acc:87.06 %
# Epoch:91/100 	 Train Loss:0.1556 Valid Loss:0.4737 	 Train Acc:94.47 %  Valid Acc:87.02 %
# Epoch:92/100 	 Train Loss:0.1577 Valid Loss:0.4732 	 Train Acc:94.33 %  Valid Acc:87.07 %
# Epoch:93/100 	 Train Loss:0.1534 Valid Loss:0.4733 	 Train Acc:94.55 %  Valid Acc:87.04 %
# Epoch:94/100 	 Train Loss:0.1555 Valid Loss:0.4715 	 Train Acc:94.46 %  Valid Acc:86.95 %
# Epoch:95/100 	 Train Loss:0.1556 Valid Loss:0.4725 	 Train Acc:94.49 %  Valid Acc:86.98 %
# Epoch:96/100 	 Train Loss:0.1566 Valid Loss:0.4711 	 Train Acc:94.51 %  Valid Acc:86.98 %
# Epoch:97/100 	 Train Loss:0.1565 Valid Loss:0.4737 	 Train Acc:94.48 %  Valid Acc:87.02 %
# Epoch:98/100 	 Train Loss:0.1556 Valid Loss:0.4747 	 Train Acc:94.41 %  Valid Acc:87.10 %
# Epoch:99/100 	 Train Loss:0.1559 Valid Loss:0.4717 	 Train Acc:94.43 %  Valid Acc:87.15 %
# [I 2024-09-28 16:32:18,921] Trial 2 finished with value: 87.03999999999999 and parameters: {'sigma_1': 2.065123292420359, 'sigma_2': 5.436066467821196, 'sigma_3': 5.832981273924858, 'sigma_4': 5.0891351563618175, 'sigma_5': 4.431298899980196, 'sigma_6': 3.9281539651115422, 'sigma_7': 3.718654151492435, 'sigma_8': 2.3594585391743967, 'sigma_9': 4.897794578624979, 'sigma_10': 2.7051246301991325, 'sigma_11': 4.321320712669025, 'sigma_12': 4.2951581233732945, 'sigma_13': 2.1831304681855697}. Best is trial 0 with value: 87.46000000000001.
# Epoch:100/100 	 Train Loss:0.1555 Valid Loss:0.4740 	 Train Acc:94.42 %  Valid Acc:87.04 %
# Epoch:1/100 	 Train Loss:1.5577 Valid Loss:1.3343 	 Train Acc:42.25 %  Valid Acc:49.94 %
# Epoch:2/100 	 Train Loss:1.1960 Valid Loss:1.1084 	 Train Acc:56.95 %  Valid Acc:60.42 %
# Epoch:3/100 	 Train Loss:1.0290 Valid Loss:0.9598 	 Train Acc:63.23 %  Valid Acc:65.27 %
# Epoch:4/100 	 Train Loss:0.9165 Valid Loss:0.8907 	 Train Acc:67.65 %  Valid Acc:68.53 %
# Epoch:5/100 	 Train Loss:0.8237 Valid Loss:0.7887 	 Train Acc:70.81 %  Valid Acc:72.54 %
# Epoch:6/100 	 Train Loss:0.7474 Valid Loss:0.8151 	 Train Acc:73.71 %  Valid Acc:72.18 %
# Epoch:7/100 	 Train Loss:0.6844 Valid Loss:0.7196 	 Train Acc:76.05 %  Valid Acc:75.21 %
# Epoch:8/100 	 Train Loss:0.6337 Valid Loss:0.6521 	 Train Acc:77.78 %  Valid Acc:77.43 %
# Epoch:9/100 	 Train Loss:0.5930 Valid Loss:0.6025 	 Train Acc:79.43 %  Valid Acc:79.27 %
# Epoch:10/100 	 Train Loss:0.5629 Valid Loss:0.5912 	 Train Acc:80.45 %  Valid Acc:80.53 %
# Epoch:11/100 	 Train Loss:0.5330 Valid Loss:0.5819 	 Train Acc:81.48 %  Valid Acc:80.72 %
# Epoch:12/100 	 Train Loss:0.5100 Valid Loss:0.5809 	 Train Acc:82.35 %  Valid Acc:80.36 %
# Epoch:13/100 	 Train Loss:0.4905 Valid Loss:0.5356 	 Train Acc:83.19 %  Valid Acc:81.84 %
# Epoch:14/100 	 Train Loss:0.4720 Valid Loss:0.5485 	 Train Acc:83.71 %  Valid Acc:82.10 %
# Epoch:15/100 	 Train Loss:0.4535 Valid Loss:0.5339 	 Train Acc:84.21 %  Valid Acc:82.47 %
# Epoch:16/100 	 Train Loss:0.4450 Valid Loss:0.5025 	 Train Acc:84.56 %  Valid Acc:83.36 %
# Epoch:17/100 	 Train Loss:0.4337 Valid Loss:0.5145 	 Train Acc:84.99 %  Valid Acc:82.98 %
# Epoch:18/100 	 Train Loss:0.4161 Valid Loss:0.4941 	 Train Acc:85.53 %  Valid Acc:83.44 %
# Epoch:19/100 	 Train Loss:0.4032 Valid Loss:0.4850 	 Train Acc:85.85 %  Valid Acc:84.41 %
# Epoch:20/100 	 Train Loss:0.3966 Valid Loss:0.4968 	 Train Acc:86.19 %  Valid Acc:84.15 %
# Epoch:21/100 	 Train Loss:0.3218 Valid Loss:0.4399 	 Train Acc:88.71 %  Valid Acc:85.84 %
# Epoch:22/100 	 Train Loss:0.3071 Valid Loss:0.4493 	 Train Acc:89.27 %  Valid Acc:85.54 %
# Epoch:23/100 	 Train Loss:0.2970 Valid Loss:0.4369 	 Train Acc:89.47 %  Valid Acc:86.18 %
# Epoch:24/100 	 Train Loss:0.2896 Valid Loss:0.4325 	 Train Acc:89.88 %  Valid Acc:85.79 %
# Epoch:25/100 	 Train Loss:0.2837 Valid Loss:0.4685 	 Train Acc:90.07 %  Valid Acc:85.60 %
# Epoch:26/100 	 Train Loss:0.2755 Valid Loss:0.4430 	 Train Acc:90.25 %  Valid Acc:86.31 %
# Epoch:27/100 	 Train Loss:0.2736 Valid Loss:0.4386 	 Train Acc:90.38 %  Valid Acc:86.30 %
# Epoch:28/100 	 Train Loss:0.2692 Valid Loss:0.4607 	 Train Acc:90.56 %  Valid Acc:85.69 %
# Epoch:29/100 	 Train Loss:0.2646 Valid Loss:0.4487 	 Train Acc:90.86 %  Valid Acc:85.98 %
# Epoch:30/100 	 Train Loss:0.2610 Valid Loss:0.4563 	 Train Acc:90.81 %  Valid Acc:85.52 %
# Epoch:31/100 	 Train Loss:0.2557 Valid Loss:0.4538 	 Train Acc:91.01 %  Valid Acc:86.23 %
# Epoch:32/100 	 Train Loss:0.2495 Valid Loss:0.4432 	 Train Acc:91.23 %  Valid Acc:86.38 %
# Epoch:33/100 	 Train Loss:0.2511 Valid Loss:0.4643 	 Train Acc:91.21 %  Valid Acc:85.78 %
# Epoch:34/100 	 Train Loss:0.2474 Valid Loss:0.4753 	 Train Acc:91.07 %  Valid Acc:86.06 %
# Epoch:35/100 	 Train Loss:0.2407 Valid Loss:0.4515 	 Train Acc:91.56 %  Valid Acc:86.47 %
# Epoch:36/100 	 Train Loss:0.2390 Valid Loss:0.4669 	 Train Acc:91.59 %  Valid Acc:85.87 %
# Epoch:37/100 	 Train Loss:0.2394 Valid Loss:0.4702 	 Train Acc:91.62 %  Valid Acc:85.79 %
# Epoch:38/100 	 Train Loss:0.2305 Valid Loss:0.4608 	 Train Acc:92.00 %  Valid Acc:86.41 %
# Epoch:39/100 	 Train Loss:0.2276 Valid Loss:0.4806 	 Train Acc:91.87 %  Valid Acc:85.79 %
# Epoch:40/100 	 Train Loss:0.2269 Valid Loss:0.4703 	 Train Acc:91.90 %  Valid Acc:85.97 %
# Epoch:41/100 	 Train Loss:0.2006 Valid Loss:0.4383 	 Train Acc:92.95 %  Valid Acc:86.85 %
# Epoch:42/100 	 Train Loss:0.1921 Valid Loss:0.4467 	 Train Acc:93.21 %  Valid Acc:86.85 %
# Epoch:43/100 	 Train Loss:0.1875 Valid Loss:0.4522 	 Train Acc:93.40 %  Valid Acc:86.75 %
# Epoch:44/100 	 Train Loss:0.1878 Valid Loss:0.4502 	 Train Acc:93.32 %  Valid Acc:86.98 %
# Epoch:45/100 	 Train Loss:0.1835 Valid Loss:0.4540 	 Train Acc:93.60 %  Valid Acc:86.83 %
# Epoch:46/100 	 Train Loss:0.1826 Valid Loss:0.4549 	 Train Acc:93.55 %  Valid Acc:87.24 %
# Epoch:47/100 	 Train Loss:0.1833 Valid Loss:0.4574 	 Train Acc:93.51 %  Valid Acc:87.22 %
# Epoch:48/100 	 Train Loss:0.1839 Valid Loss:0.4655 	 Train Acc:93.39 %  Valid Acc:86.90 %
# Epoch:49/100 	 Train Loss:0.1785 Valid Loss:0.4585 	 Train Acc:93.70 %  Valid Acc:87.15 %
# Epoch:50/100 	 Train Loss:0.1789 Valid Loss:0.4608 	 Train Acc:93.60 %  Valid Acc:86.85 %
# Epoch:51/100 	 Train Loss:0.1769 Valid Loss:0.4583 	 Train Acc:93.66 %  Valid Acc:86.97 %
# Epoch:52/100 	 Train Loss:0.1796 Valid Loss:0.4701 	 Train Acc:93.70 %  Valid Acc:87.03 %
# Epoch:53/100 	 Train Loss:0.1737 Valid Loss:0.4705 	 Train Acc:93.84 %  Valid Acc:87.10 %
# Epoch:54/100 	 Train Loss:0.1716 Valid Loss:0.4712 	 Train Acc:93.91 %  Valid Acc:87.20 %
# Epoch:55/100 	 Train Loss:0.1733 Valid Loss:0.4688 	 Train Acc:93.81 %  Valid Acc:86.88 %
# Epoch:56/100 	 Train Loss:0.1682 Valid Loss:0.4588 	 Train Acc:93.96 %  Valid Acc:87.06 %
# Epoch:57/100 	 Train Loss:0.1695 Valid Loss:0.4693 	 Train Acc:93.91 %  Valid Acc:87.24 %
# Epoch:58/100 	 Train Loss:0.1667 Valid Loss:0.4775 	 Train Acc:94.08 %  Valid Acc:87.03 %
# Epoch:59/100 	 Train Loss:0.1672 Valid Loss:0.4700 	 Train Acc:94.06 %  Valid Acc:86.90 %
# Epoch:60/100 	 Train Loss:0.1667 Valid Loss:0.4693 	 Train Acc:94.04 %  Valid Acc:87.02 %
# Epoch:61/100 	 Train Loss:0.1578 Valid Loss:0.4697 	 Train Acc:94.53 %  Valid Acc:87.28 %
# Epoch:62/100 	 Train Loss:0.1538 Valid Loss:0.4667 	 Train Acc:94.54 %  Valid Acc:87.23 %
# Epoch:63/100 	 Train Loss:0.1539 Valid Loss:0.4697 	 Train Acc:94.58 %  Valid Acc:87.22 %
# Epoch:64/100 	 Train Loss:0.1499 Valid Loss:0.4709 	 Train Acc:94.68 %  Valid Acc:87.14 %
# Epoch:65/100 	 Train Loss:0.1496 Valid Loss:0.4754 	 Train Acc:94.63 %  Valid Acc:87.23 %
# Epoch:66/100 	 Train Loss:0.1522 Valid Loss:0.4750 	 Train Acc:94.52 %  Valid Acc:87.27 %
# Epoch:67/100 	 Train Loss:0.1484 Valid Loss:0.4744 	 Train Acc:94.71 %  Valid Acc:87.22 %
# Epoch:68/100 	 Train Loss:0.1508 Valid Loss:0.4804 	 Train Acc:94.68 %  Valid Acc:87.22 %
# Epoch:69/100 	 Train Loss:0.1499 Valid Loss:0.4798 	 Train Acc:94.73 %  Valid Acc:87.27 %
# Epoch:70/100 	 Train Loss:0.1488 Valid Loss:0.4750 	 Train Acc:94.80 %  Valid Acc:87.34 %
# Epoch:71/100 	 Train Loss:0.1495 Valid Loss:0.4767 	 Train Acc:94.70 %  Valid Acc:87.21 %
# Epoch:72/100 	 Train Loss:0.1480 Valid Loss:0.4829 	 Train Acc:94.72 %  Valid Acc:87.30 %
# Epoch:73/100 	 Train Loss:0.1460 Valid Loss:0.4821 	 Train Acc:94.75 %  Valid Acc:87.12 %
# Epoch:74/100 	 Train Loss:0.1438 Valid Loss:0.4807 	 Train Acc:94.90 %  Valid Acc:87.49 %
# Epoch:75/100 	 Train Loss:0.1449 Valid Loss:0.4798 	 Train Acc:94.92 %  Valid Acc:87.28 %
# Epoch:76/100 	 Train Loss:0.1427 Valid Loss:0.4815 	 Train Acc:94.90 %  Valid Acc:87.20 %
# Epoch:77/100 	 Train Loss:0.1432 Valid Loss:0.4859 	 Train Acc:94.84 %  Valid Acc:87.31 %
# Epoch:78/100 	 Train Loss:0.1481 Valid Loss:0.4830 	 Train Acc:94.79 %  Valid Acc:87.26 %
# Epoch:79/100 	 Train Loss:0.1450 Valid Loss:0.4863 	 Train Acc:94.79 %  Valid Acc:87.14 %
# Epoch:80/100 	 Train Loss:0.1453 Valid Loss:0.4878 	 Train Acc:94.93 %  Valid Acc:87.17 %
# Epoch:81/100 	 Train Loss:0.1415 Valid Loss:0.4850 	 Train Acc:95.01 %  Valid Acc:87.20 %
# Epoch:82/100 	 Train Loss:0.1408 Valid Loss:0.4840 	 Train Acc:95.02 %  Valid Acc:87.31 %
# Epoch:83/100 	 Train Loss:0.1393 Valid Loss:0.4842 	 Train Acc:95.08 %  Valid Acc:87.17 %
# Epoch:84/100 	 Train Loss:0.1411 Valid Loss:0.4836 	 Train Acc:94.99 %  Valid Acc:87.20 %
# Epoch:85/100 	 Train Loss:0.1394 Valid Loss:0.4867 	 Train Acc:95.03 %  Valid Acc:87.27 %
# Epoch:86/100 	 Train Loss:0.1392 Valid Loss:0.4848 	 Train Acc:94.95 %  Valid Acc:87.39 %
# Epoch:87/100 	 Train Loss:0.1388 Valid Loss:0.4835 	 Train Acc:95.12 %  Valid Acc:87.30 %
# Epoch:88/100 	 Train Loss:0.1364 Valid Loss:0.4843 	 Train Acc:95.25 %  Valid Acc:87.32 %
# Epoch:89/100 	 Train Loss:0.1397 Valid Loss:0.4870 	 Train Acc:95.10 %  Valid Acc:87.12 %
# Epoch:90/100 	 Train Loss:0.1373 Valid Loss:0.4881 	 Train Acc:95.05 %  Valid Acc:87.18 %
# Epoch:91/100 	 Train Loss:0.1401 Valid Loss:0.4861 	 Train Acc:95.07 %  Valid Acc:87.17 %
# Epoch:92/100 	 Train Loss:0.1381 Valid Loss:0.4865 	 Train Acc:95.08 %  Valid Acc:87.33 %
# Epoch:93/100 	 Train Loss:0.1371 Valid Loss:0.4880 	 Train Acc:95.16 %  Valid Acc:87.27 %
# Epoch:94/100 	 Train Loss:0.1365 Valid Loss:0.4899 	 Train Acc:95.17 %  Valid Acc:87.23 %
# Epoch:95/100 	 Train Loss:0.1367 Valid Loss:0.4918 	 Train Acc:95.25 %  Valid Acc:87.26 %
# Epoch:96/100 	 Train Loss:0.1359 Valid Loss:0.4923 	 Train Acc:95.10 %  Valid Acc:87.20 %
# Epoch:97/100 	 Train Loss:0.1385 Valid Loss:0.4885 	 Train Acc:95.10 %  Valid Acc:87.24 %
# Epoch:98/100 	 Train Loss:0.1375 Valid Loss:0.4876 	 Train Acc:95.10 %  Valid Acc:87.35 %
# Epoch:99/100 	 Train Loss:0.1391 Valid Loss:0.4875 	 Train Acc:95.08 %  Valid Acc:87.13 %
# [I 2024-09-28 17:48:43,681] Trial 3 finished with value: 87.35000000000001 and parameters: {'sigma_1': 3.4109643054180365, 'sigma_2': 4.239093399661501, 'sigma_3': 5.784842941156161, 'sigma_4': 5.902469413494353, 'sigma_5': 2.0138665258839143, 'sigma_6': 3.7031548542330937, 'sigma_7': 5.2317653521705, 'sigma_8': 5.678645452804165, 'sigma_9': 5.613058672041527, 'sigma_10': 4.493496657846066, 'sigma_11': 3.0249119890635985, 'sigma_12': 3.1902679353125065, 'sigma_13': 2.0458018826374316}. Best is trial 0 with value: 87.46000000000001.
# Epoch:100/100 	 Train Loss:0.1364 Valid Loss:0.4903 	 Train Acc:95.18 %  Valid Acc:87.35 %
# Epoch:1/100 	 Train Loss:1.5831 Valid Loss:1.3492 	 Train Acc:41.19 %  Valid Acc:50.52 %
# Epoch:2/100 	 Train Loss:1.2233 Valid Loss:1.0718 	 Train Acc:55.99 %  Valid Acc:61.33 %
# Epoch:3/100 	 Train Loss:1.0385 Valid Loss:1.0137 	 Train Acc:62.87 %  Valid Acc:64.91 %
# Epoch:4/100 	 Train Loss:0.9287 Valid Loss:0.8931 	 Train Acc:67.17 %  Valid Acc:68.81 %
# Epoch:5/100 	 Train Loss:0.8367 Valid Loss:0.8360 	 Train Acc:70.49 %  Valid Acc:71.33 %
# Epoch:6/100 	 Train Loss:0.7648 Valid Loss:0.7465 	 Train Acc:73.01 %  Valid Acc:74.20 %
# Epoch:7/100 	 Train Loss:0.7069 Valid Loss:0.6991 	 Train Acc:75.21 %  Valid Acc:75.78 %
# Epoch:8/100 	 Train Loss:0.6602 Valid Loss:0.6965 	 Train Acc:76.87 %  Valid Acc:76.60 %
# Epoch:9/100 	 Train Loss:0.6218 Valid Loss:0.6117 	 Train Acc:78.30 %  Valid Acc:79.01 %
# Epoch:10/100 	 Train Loss:0.5935 Valid Loss:0.6118 	 Train Acc:79.23 %  Valid Acc:79.31 %
# Epoch:11/100 	 Train Loss:0.5711 Valid Loss:0.5843 	 Train Acc:80.26 %  Valid Acc:80.39 %
# Epoch:12/100 	 Train Loss:0.5400 Valid Loss:0.5659 	 Train Acc:81.18 %  Valid Acc:81.04 %
# Epoch:13/100 	 Train Loss:0.5204 Valid Loss:0.5960 	 Train Acc:81.86 %  Valid Acc:79.65 %
# Epoch:14/100 	 Train Loss:0.5032 Valid Loss:0.5369 	 Train Acc:82.68 %  Valid Acc:81.68 %
# Epoch:15/100 	 Train Loss:0.4880 Valid Loss:0.5319 	 Train Acc:83.10 %  Valid Acc:82.14 %
# Epoch:16/100 	 Train Loss:0.4727 Valid Loss:0.5527 	 Train Acc:83.59 %  Valid Acc:81.96 %
# Epoch:17/100 	 Train Loss:0.4605 Valid Loss:0.5395 	 Train Acc:83.98 %  Valid Acc:82.33 %
# Epoch:18/100 	 Train Loss:0.4480 Valid Loss:0.5192 	 Train Acc:84.43 %  Valid Acc:82.69 %
# Epoch:19/100 	 Train Loss:0.4375 Valid Loss:0.5421 	 Train Acc:84.74 %  Valid Acc:82.16 %
# Epoch:20/100 	 Train Loss:0.4217 Valid Loss:0.5156 	 Train Acc:85.39 %  Valid Acc:83.12 %
# Epoch:21/100 	 Train Loss:0.3469 Valid Loss:0.4664 	 Train Acc:87.99 %  Valid Acc:84.82 %
# Epoch:22/100 	 Train Loss:0.3270 Valid Loss:0.4460 	 Train Acc:88.64 %  Valid Acc:85.11 %
# Epoch:23/100 	 Train Loss:0.3189 Valid Loss:0.4544 	 Train Acc:88.92 %  Valid Acc:85.50 %
# Epoch:24/100 	 Train Loss:0.3118 Valid Loss:0.4456 	 Train Acc:89.08 %  Valid Acc:85.68 %
# Epoch:25/100 	 Train Loss:0.3076 Valid Loss:0.4600 	 Train Acc:89.31 %  Valid Acc:85.28 %
# Epoch:26/100 	 Train Loss:0.3023 Valid Loss:0.4491 	 Train Acc:89.47 %  Valid Acc:85.46 %
# Epoch:27/100 	 Train Loss:0.2953 Valid Loss:0.4590 	 Train Acc:89.61 %  Valid Acc:85.16 %
# Epoch:28/100 	 Train Loss:0.2882 Valid Loss:0.4490 	 Train Acc:89.90 %  Valid Acc:85.45 %
# Epoch:29/100 	 Train Loss:0.2897 Valid Loss:0.4561 	 Train Acc:89.80 %  Valid Acc:85.28 %
# Epoch:30/100 	 Train Loss:0.2860 Valid Loss:0.4693 	 Train Acc:89.91 %  Valid Acc:85.37 %
# Epoch:31/100 	 Train Loss:0.2784 Valid Loss:0.4557 	 Train Acc:90.21 %  Valid Acc:85.71 %
# Epoch:32/100 	 Train Loss:0.2737 Valid Loss:0.4648 	 Train Acc:90.34 %  Valid Acc:85.63 %
# Epoch:33/100 	 Train Loss:0.2731 Valid Loss:0.4633 	 Train Acc:90.35 %  Valid Acc:85.32 %
# Epoch:34/100 	 Train Loss:0.2677 Valid Loss:0.4522 	 Train Acc:90.60 %  Valid Acc:85.63 %
# Epoch:35/100 	 Train Loss:0.2600 Valid Loss:0.4795 	 Train Acc:90.90 %  Valid Acc:85.58 %
# Epoch:36/100 	 Train Loss:0.2603 Valid Loss:0.4447 	 Train Acc:90.78 %  Valid Acc:86.03 %
# Epoch:37/100 	 Train Loss:0.2555 Valid Loss:0.4733 	 Train Acc:90.82 %  Valid Acc:85.91 %
# Epoch:38/100 	 Train Loss:0.2549 Valid Loss:0.4532 	 Train Acc:91.02 %  Valid Acc:85.79 %
# Epoch:39/100 	 Train Loss:0.2487 Valid Loss:0.4672 	 Train Acc:91.26 %  Valid Acc:85.65 %
# Epoch:40/100 	 Train Loss:0.2455 Valid Loss:0.4742 	 Train Acc:91.38 %  Valid Acc:85.54 %
# Epoch:41/100 	 Train Loss:0.2184 Valid Loss:0.4506 	 Train Acc:92.27 %  Valid Acc:86.41 %
# Epoch:42/100 	 Train Loss:0.2107 Valid Loss:0.4514 	 Train Acc:92.63 %  Valid Acc:86.77 %
# Epoch:43/100 	 Train Loss:0.2100 Valid Loss:0.4466 	 Train Acc:92.68 %  Valid Acc:86.58 %
# Epoch:44/100 	 Train Loss:0.2054 Valid Loss:0.4693 	 Train Acc:92.64 %  Valid Acc:86.38 %
# Epoch:45/100 	 Train Loss:0.2048 Valid Loss:0.4663 	 Train Acc:92.78 %  Valid Acc:86.53 %
# Epoch:46/100 	 Train Loss:0.2016 Valid Loss:0.4533 	 Train Acc:92.91 %  Valid Acc:86.75 %
# Epoch:47/100 	 Train Loss:0.1990 Valid Loss:0.4633 	 Train Acc:92.88 %  Valid Acc:86.55 %
# Epoch:48/100 	 Train Loss:0.1988 Valid Loss:0.4661 	 Train Acc:92.84 %  Valid Acc:86.62 %
# Epoch:49/100 	 Train Loss:0.1968 Valid Loss:0.4609 	 Train Acc:92.95 %  Valid Acc:86.61 %
# Epoch:50/100 	 Train Loss:0.1995 Valid Loss:0.4647 	 Train Acc:93.11 %  Valid Acc:86.45 %
# Epoch:51/100 	 Train Loss:0.1939 Valid Loss:0.4604 	 Train Acc:93.11 %  Valid Acc:86.57 %
# Epoch:52/100 	 Train Loss:0.1945 Valid Loss:0.4707 	 Train Acc:93.21 %  Valid Acc:86.41 %
# Epoch:53/100 	 Train Loss:0.1930 Valid Loss:0.4679 	 Train Acc:93.11 %  Valid Acc:86.74 %
# Epoch:54/100 	 Train Loss:0.1900 Valid Loss:0.4743 	 Train Acc:93.30 %  Valid Acc:86.52 %
# Epoch:55/100 	 Train Loss:0.1905 Valid Loss:0.4711 	 Train Acc:93.26 %  Valid Acc:86.60 %
# Epoch:56/100 	 Train Loss:0.1885 Valid Loss:0.4843 	 Train Acc:93.34 %  Valid Acc:86.24 %
# Epoch:57/100 	 Train Loss:0.1904 Valid Loss:0.4699 	 Train Acc:93.22 %  Valid Acc:86.52 %
# Epoch:58/100 	 Train Loss:0.1894 Valid Loss:0.4790 	 Train Acc:93.30 %  Valid Acc:86.55 %
# Epoch:59/100 	 Train Loss:0.1836 Valid Loss:0.4749 	 Train Acc:93.58 %  Valid Acc:86.82 %
# Epoch:60/100 	 Train Loss:0.1860 Valid Loss:0.4737 	 Train Acc:93.44 %  Valid Acc:86.97 %
# Epoch:61/100 	 Train Loss:0.1726 Valid Loss:0.4707 	 Train Acc:93.90 %  Valid Acc:87.02 %
# Epoch:62/100 	 Train Loss:0.1698 Valid Loss:0.4728 	 Train Acc:93.95 %  Valid Acc:86.98 %
# Epoch:63/100 	 Train Loss:0.1680 Valid Loss:0.4773 	 Train Acc:93.98 %  Valid Acc:87.05 %
# Epoch:64/100 	 Train Loss:0.1714 Valid Loss:0.4722 	 Train Acc:94.02 %  Valid Acc:87.06 %
# Epoch:65/100 	 Train Loss:0.1702 Valid Loss:0.4732 	 Train Acc:94.04 %  Valid Acc:86.99 %
# Epoch:66/100 	 Train Loss:0.1706 Valid Loss:0.4771 	 Train Acc:93.94 %  Valid Acc:86.80 %
# Epoch:67/100 	 Train Loss:0.1684 Valid Loss:0.4747 	 Train Acc:94.10 %  Valid Acc:86.82 %
# Epoch:68/100 	 Train Loss:0.1647 Valid Loss:0.4787 	 Train Acc:94.19 %  Valid Acc:86.85 %
# Epoch:69/100 	 Train Loss:0.1662 Valid Loss:0.4772 	 Train Acc:94.06 %  Valid Acc:87.18 %
# Epoch:70/100 	 Train Loss:0.1640 Valid Loss:0.4794 	 Train Acc:94.30 %  Valid Acc:87.13 %
# Epoch:71/100 	 Train Loss:0.1671 Valid Loss:0.4820 	 Train Acc:93.96 %  Valid Acc:86.81 %
# Epoch:72/100 	 Train Loss:0.1653 Valid Loss:0.4776 	 Train Acc:94.13 %  Valid Acc:86.89 %
# Epoch:73/100 	 Train Loss:0.1621 Valid Loss:0.4881 	 Train Acc:94.25 %  Valid Acc:86.97 %
# Epoch:74/100 	 Train Loss:0.1643 Valid Loss:0.4807 	 Train Acc:94.15 %  Valid Acc:87.04 %
# Epoch:75/100 	 Train Loss:0.1617 Valid Loss:0.4820 	 Train Acc:94.31 %  Valid Acc:87.13 %
# Epoch:76/100 	 Train Loss:0.1614 Valid Loss:0.4865 	 Train Acc:94.41 %  Valid Acc:86.86 %
# Epoch:77/100 	 Train Loss:0.1627 Valid Loss:0.4852 	 Train Acc:94.36 %  Valid Acc:87.06 %
# Epoch:78/100 	 Train Loss:0.1664 Valid Loss:0.4777 	 Train Acc:94.07 %  Valid Acc:87.05 %
# Epoch:79/100 	 Train Loss:0.1616 Valid Loss:0.4816 	 Train Acc:94.25 %  Valid Acc:87.04 %
# Epoch:80/100 	 Train Loss:0.1594 Valid Loss:0.4835 	 Train Acc:94.42 %  Valid Acc:87.03 %
# Epoch:81/100 	 Train Loss:0.1595 Valid Loss:0.4814 	 Train Acc:94.41 %  Valid Acc:87.13 %
# Epoch:82/100 	 Train Loss:0.1612 Valid Loss:0.4842 	 Train Acc:94.40 %  Valid Acc:87.05 %
# Epoch:83/100 	 Train Loss:0.1582 Valid Loss:0.4842 	 Train Acc:94.39 %  Valid Acc:87.23 %
# Epoch:84/100 	 Train Loss:0.1555 Valid Loss:0.4878 	 Train Acc:94.54 %  Valid Acc:87.02 %
# Epoch:85/100 	 Train Loss:0.1535 Valid Loss:0.4845 	 Train Acc:94.58 %  Valid Acc:87.20 %
# Epoch:86/100 	 Train Loss:0.1572 Valid Loss:0.4833 	 Train Acc:94.48 %  Valid Acc:87.06 %
# Epoch:87/100 	 Train Loss:0.1554 Valid Loss:0.4822 	 Train Acc:94.52 %  Valid Acc:87.13 %
# Epoch:88/100 	 Train Loss:0.1594 Valid Loss:0.4844 	 Train Acc:94.39 %  Valid Acc:87.22 %
# Epoch:89/100 	 Train Loss:0.1566 Valid Loss:0.4835 	 Train Acc:94.37 %  Valid Acc:87.13 %
# Epoch:90/100 	 Train Loss:0.1535 Valid Loss:0.4835 	 Train Acc:94.59 %  Valid Acc:87.16 %
# Epoch:91/100 	 Train Loss:0.1515 Valid Loss:0.4862 	 Train Acc:94.61 %  Valid Acc:87.06 %
# Epoch:92/100 	 Train Loss:0.1548 Valid Loss:0.4856 	 Train Acc:94.52 %  Valid Acc:87.16 %
# Epoch:93/100 	 Train Loss:0.1549 Valid Loss:0.4871 	 Train Acc:94.51 %  Valid Acc:87.08 %
# Epoch:94/100 	 Train Loss:0.1535 Valid Loss:0.4900 	 Train Acc:94.52 %  Valid Acc:87.08 %
# Epoch:95/100 	 Train Loss:0.1571 Valid Loss:0.4896 	 Train Acc:94.47 %  Valid Acc:87.13 %
# Epoch:96/100 	 Train Loss:0.1536 Valid Loss:0.4887 	 Train Acc:94.61 %  Valid Acc:87.02 %
# Epoch:97/100 	 Train Loss:0.1493 Valid Loss:0.4892 	 Train Acc:94.62 %  Valid Acc:86.99 %
# Epoch:98/100 	 Train Loss:0.1530 Valid Loss:0.4874 	 Train Acc:94.59 %  Valid Acc:87.01 %
# Epoch:99/100 	 Train Loss:0.1536 Valid Loss:0.4897 	 Train Acc:94.50 %  Valid Acc:86.97 %
# [I 2024-09-28 19:04:39,602] Trial 4 finished with value: 87.03999999999999 and parameters: {'sigma_1': 5.617047761870667, 'sigma_2': 4.72737567067329, 'sigma_3': 5.434397658303169, 'sigma_4': 4.897073209438389, 'sigma_5': 4.616163693671034, 'sigma_6': 4.517794610438461, 'sigma_7': 5.024062165296797, 'sigma_8': 5.269806195885671, 'sigma_9': 2.1902030364153915, 'sigma_10': 3.047303028114354, 'sigma_11': 3.8207894034426646, 'sigma_12': 2.9856909545043755, 'sigma_13': 4.576797231258607}. Best is trial 0 with value: 87.46000000000001.
# Epoch:100/100 	 Train Loss:0.1525 Valid Loss:0.4894 	 Train Acc:94.58 %  Valid Acc:87.04 %
# Epoch:1/100 	 Train Loss:1.5265 Valid Loss:1.3479 	 Train Acc:43.42 %  Valid Acc:52.49 %
# Epoch:2/100 	 Train Loss:1.1566 Valid Loss:1.0261 	 Train Acc:58.17 %  Valid Acc:63.45 %
# ...
# Epoch:40/100 	 Train Loss:0.2321 Valid Loss:0.4462 	 Train Acc:91.90 %  Valid Acc:86.36 %
# Epoch:41/100 	 Train Loss:0.2046 Valid Loss:0.4372 	 Train Acc:92.69 %  Valid Acc:86.92 %
# Epoch:42/100 	 Train Loss:0.1962 Valid Loss:0.4376 	 Train Acc:93.06 %  Valid Acc:87.05 %
# Epoch:43/100 	 Train Loss:0.1938 Valid Loss:0.4462 	 Train Acc:93.17 %  Valid Acc:87.26 %
# Epoch:44/100 	 Train Loss:0.1900 Valid Loss:0.4512 	 Train Acc:93.38 %  Valid Acc:87.12 %
# Epoch:45/100 	 Train Loss:0.1889 Valid Loss:0.4495 	 Train Acc:93.41 %  Valid Acc:86.89 %
# Epoch:46/100 	 Train Loss:0.1898 Valid Loss:0.4477 	 Train Acc:93.16 %  Valid Acc:87.25 %
# Epoch:47/100 	 Train Loss:0.1882 Valid Loss:0.4479 	 Train Acc:93.24 %  Valid Acc:87.19 %
# Epoch:48/100 	 Train Loss:0.1854 Valid Loss:0.4498 	 Train Acc:93.47 %  Valid Acc:87.29 %
# Epoch:49/100 	 Train Loss:0.1823 Valid Loss:0.4554 	 Train Acc:93.39 %  Valid Acc:87.05 %
# Epoch:50/100 	 Train Loss:0.1831 Valid Loss:0.4603 	 Train Acc:93.51 %  Valid Acc:87.08 %
# Epoch:51/100 	 Train Loss:0.1784 Valid Loss:0.4618 	 Train Acc:93.63 %  Valid Acc:87.01 %
# Epoch:52/100 	 Train Loss:0.1791 Valid Loss:0.4692 	 Train Acc:93.62 %  Valid Acc:87.03 %
# Epoch:53/100 	 Train Loss:0.1777 Valid Loss:0.4650 	 Train Acc:93.61 %  Valid Acc:87.20 %
# Epoch:54/100 	 Train Loss:0.1753 Valid Loss:0.4653 	 Train Acc:93.86 %  Valid Acc:86.79 %
# Epoch:55/100 	 Train Loss:0.1722 Valid Loss:0.4700 	 Train Acc:93.88 %  Valid Acc:87.09 %
# Epoch:56/100 	 Train Loss:0.1743 Valid Loss:0.4778 	 Train Acc:93.86 %  Valid Acc:86.95 %
# Epoch:57/100 	 Train Loss:0.1749 Valid Loss:0.4697 	 Train Acc:93.77 %  Valid Acc:87.20 %
# Epoch:58/100 	 Train Loss:0.1702 Valid Loss:0.4617 	 Train Acc:94.00 %  Valid Acc:87.43 %
# Epoch:59/100 	 Train Loss:0.1707 Valid Loss:0.4841 	 Train Acc:93.99 %  Valid Acc:86.76 %
# Epoch:60/100 	 Train Loss:0.1692 Valid Loss:0.4657 	 Train Acc:93.93 %  Valid Acc:87.34 %
# Epoch:61/100 	 Train Loss:0.1598 Valid Loss:0.4677 	 Train Acc:94.41 %  Valid Acc:87.32 %
# Epoch:62/100 	 Train Loss:0.1584 Valid Loss:0.4667 	 Train Acc:94.35 %  Valid Acc:87.55 %
# Epoch:63/100 	 Train Loss:0.1555 Valid Loss:0.4720 	 Train Acc:94.48 %  Valid Acc:87.55 %
# Epoch:64/100 	 Train Loss:0.1552 Valid Loss:0.4764 	 Train Acc:94.45 %  Valid Acc:87.28 %
# Epoch:65/100 	 Train Loss:0.1577 Valid Loss:0.4749 	 Train Acc:94.40 %  Valid Acc:87.27 %
# Epoch:66/100 	 Train Loss:0.1532 Valid Loss:0.4745 	 Train Acc:94.58 %  Valid Acc:87.44 %
# Epoch:67/100 	 Train Loss:0.1550 Valid Loss:0.4737 	 Train Acc:94.48 %  Valid Acc:87.27 %
# Epoch:68/100 	 Train Loss:0.1548 Valid Loss:0.4779 	 Train Acc:94.52 %  Valid Acc:87.29 %
# Epoch:69/100 	 Train Loss:0.1526 Valid Loss:0.4745 	 Train Acc:94.65 %  Valid Acc:87.30 %
# Epoch:70/100 	 Train Loss:0.1511 Valid Loss:0.4747 	 Train Acc:94.55 %  Valid Acc:87.31 %
# Epoch:71/100 	 Train Loss:0.1511 Valid Loss:0.4809 	 Train Acc:94.70 %  Valid Acc:87.37 %
# Epoch:72/100 	 Train Loss:0.1494 Valid Loss:0.4786 	 Train Acc:94.66 %  Valid Acc:87.30 %
# Epoch:73/100 	 Train Loss:0.1525 Valid Loss:0.4787 	 Train Acc:94.49 %  Valid Acc:87.36 %
# Epoch:74/100 	 Train Loss:0.1482 Valid Loss:0.4836 	 Train Acc:94.71 %  Valid Acc:87.20 %
# Epoch:75/100 	 Train Loss:0.1484 Valid Loss:0.4811 	 Train Acc:94.67 %  Valid Acc:87.27 %
# Epoch:76/100 	 Train Loss:0.1480 Valid Loss:0.4840 	 Train Acc:94.78 %  Valid Acc:87.36 %
# Epoch:77/100 	 Train Loss:0.1476 Valid Loss:0.4842 	 Train Acc:94.72 %  Valid Acc:87.27 %
# Epoch:78/100 	 Train Loss:0.1512 Valid Loss:0.4802 	 Train Acc:94.57 %  Valid Acc:87.40 %
# Epoch:79/100 	 Train Loss:0.1487 Valid Loss:0.4807 	 Train Acc:94.79 %  Valid Acc:87.28 %
# Epoch:80/100 	 Train Loss:0.1468 Valid Loss:0.4855 	 Train Acc:94.81 %  Valid Acc:87.35 %
# Epoch:81/100 	 Train Loss:0.1437 Valid Loss:0.4867 	 Train Acc:94.92 %  Valid Acc:87.26 %
# Epoch:82/100 	 Train Loss:0.1449 Valid Loss:0.4849 	 Train Acc:94.82 %  Valid Acc:87.43 %
# Epoch:83/100 	 Train Loss:0.1416 Valid Loss:0.4845 	 Train Acc:95.04 %  Valid Acc:87.43 %
# Epoch:84/100 	 Train Loss:0.1402 Valid Loss:0.4891 	 Train Acc:95.20 %  Valid Acc:87.32 %
# Epoch:85/100 	 Train Loss:0.1429 Valid Loss:0.4856 	 Train Acc:94.91 %  Valid Acc:87.47 %
# Epoch:86/100 	 Train Loss:0.1430 Valid Loss:0.4851 	 Train Acc:94.92 %  Valid Acc:87.46 %
# Epoch:87/100 	 Train Loss:0.1388 Valid Loss:0.4881 	 Train Acc:95.07 %  Valid Acc:87.37 %
# Epoch:88/100 	 Train Loss:0.1439 Valid Loss:0.4894 	 Train Acc:94.91 %  Valid Acc:87.46 %
# Epoch:89/100 	 Train Loss:0.1399 Valid Loss:0.4888 	 Train Acc:95.06 %  Valid Acc:87.33 %
# Epoch:90/100 	 Train Loss:0.1382 Valid Loss:0.4910 	 Train Acc:95.11 %  Valid Acc:87.49 %
# Epoch:91/100 	 Train Loss:0.1391 Valid Loss:0.4881 	 Train Acc:95.08 %  Valid Acc:87.36 %
# Epoch:92/100 	 Train Loss:0.1404 Valid Loss:0.4904 	 Train Acc:94.97 %  Valid Acc:87.20 %
# Epoch:93/100 	 Train Loss:0.1404 Valid Loss:0.4911 	 Train Acc:95.08 %  Valid Acc:87.30 %
# Epoch:94/100 	 Train Loss:0.1385 Valid Loss:0.4897 	 Train Acc:95.02 %  Valid Acc:87.31 %
# Epoch:95/100 	 Train Loss:0.1385 Valid Loss:0.4903 	 Train Acc:95.10 %  Valid Acc:87.32 %
# Epoch:96/100 	 Train Loss:0.1397 Valid Loss:0.4919 	 Train Acc:94.95 %  Valid Acc:87.41 %
# Epoch:97/100 	 Train Loss:0.1398 Valid Loss:0.4907 	 Train Acc:95.04 %  Valid Acc:87.30 %
# Epoch:98/100 	 Train Loss:0.1399 Valid Loss:0.4910 	 Train Acc:95.04 %  Valid Acc:87.41 %
# Epoch:99/100 	 Train Loss:0.1387 Valid Loss:0.4904 	 Train Acc:94.99 %  Valid Acc:87.51 %
# [I 2024-09-29 12:28:16,248] Trial 18 finished with value: 87.35000000000001 and parameters: {'sigma_1': 5.470405003288581, 'sigma_2': 4.376988088021423, 'sigma_3': 3.4406343431737767, 'sigma_4': 2.365674717692928, 'sigma_5': 2.5254749387211586, 'sigma_6': 2.591059747502902, 'sigma_7': 3.5647256656621313, 'sigma_8': 4.797334216205891, 'sigma_9': 2.577081901694997, 'sigma_10': 3.5541924011226835, 'sigma_11': 3.364818206427023, 'sigma_12': 2.6109904675759537, 'sigma_13': 2.747362372834456}. Best is trial 5 with value: 87.79.
# Epoch:100/100 	 Train Loss:0.1383 Valid Loss:0.4968 	 Train Acc:95.09 %  Valid Acc:87.35 %
# Epoch:1/100 	 Train Loss:1.5857 Valid Loss:1.4090 	 Train Acc:40.77 %  Valid Acc:48.31 %
# Epoch:2/100 	 Train Loss:1.2133 Valid Loss:1.0512 	 Train Acc:56.01 %  Valid Acc:62.28 %
# Epoch:3/100 	 Train Loss:1.0421 Valid Loss:1.0218 	 Train Acc:62.75 %  Valid Acc:63.28 %
# Epoch:4/100 	 Train Loss:0.9319 Valid Loss:0.8893 	 Train Acc:67.07 %  Valid Acc:68.27 %
# Epoch:5/100 	 Train Loss:0.8432 Valid Loss:0.8057 	 Train Acc:70.14 %  Valid Acc:72.63 %
# Epoch:6/100 	 Train Loss:0.7655 Valid Loss:0.7680 	 Train Acc:73.04 %  Valid Acc:73.32 %
# Epoch:7/100 	 Train Loss:0.7062 Valid Loss:0.7024 	 Train Acc:75.35 %  Valid Acc:75.91 %
# Epoch:8/100 	 Train Loss:0.6582 Valid Loss:0.6620 	 Train Acc:77.14 %  Valid Acc:78.00 %
# Epoch:9/100 	 Train Loss:0.6159 Valid Loss:0.6097 	 Train Acc:78.49 %  Valid Acc:79.52 %
# Epoch:10/100 	 Train Loss:0.5866 Valid Loss:0.6277 	 Train Acc:79.62 %  Valid Acc:78.91 %
# Epoch:11/100 	 Train Loss:0.5531 Valid Loss:0.6758 	 Train Acc:80.79 %  Valid Acc:78.02 %
# Epoch:12/100 	 Train Loss:0.5276 Valid Loss:0.5680 	 Train Acc:81.90 %  Valid Acc:81.11 %
# Epoch:13/100 	 Train Loss:0.5046 Valid Loss:0.5633 	 Train Acc:82.41 %  Valid Acc:81.56 %
# Epoch:14/100 	 Train Loss:0.4895 Valid Loss:0.5605 	 Train Acc:83.12 %  Valid Acc:81.65 %
# Epoch:15/100 	 Train Loss:0.4736 Valid Loss:0.5519 	 Train Acc:83.45 %  Valid Acc:81.91 %
# Epoch:16/100 	 Train Loss:0.4528 Valid Loss:0.5188 	 Train Acc:84.03 %  Valid Acc:82.46 %
# Epoch:17/100 	 Train Loss:0.4459 Valid Loss:0.5429 	 Train Acc:84.62 %  Valid Acc:82.42 %
# Epoch:18/100 	 Train Loss:0.4307 Valid Loss:0.5004 	 Train Acc:84.99 %  Valid Acc:83.27 %
# Epoch:19/100 	 Train Loss:0.4159 Valid Loss:0.5166 	 Train Acc:85.53 %  Valid Acc:83.50 %
# Epoch:20/100 	 Train Loss:0.4092 Valid Loss:0.5251 	 Train Acc:85.80 %  Valid Acc:83.27 %
# Epoch:21/100 	 Train Loss:0.3306 Valid Loss:0.4602 	 Train Acc:88.51 %  Valid Acc:85.65 %
# Epoch:22/100 	 Train Loss:0.3102 Valid Loss:0.4536 	 Train Acc:89.24 %  Valid Acc:85.88 %
# Epoch:23/100 	 Train Loss:0.3052 Valid Loss:0.4517 	 Train Acc:89.38 %  Valid Acc:86.20 %
# Epoch:24/100 	 Train Loss:0.2980 Valid Loss:0.4518 	 Train Acc:89.58 %  Valid Acc:85.66 %
# Epoch:25/100 	 Train Loss:0.2924 Valid Loss:0.4450 	 Train Acc:89.89 %  Valid Acc:86.19 %
# Epoch:26/100 	 Train Loss:0.2819 Valid Loss:0.4540 	 Train Acc:90.04 %  Valid Acc:86.19 %
# Epoch:27/100 	 Train Loss:0.2759 Valid Loss:0.4548 	 Train Acc:90.37 %  Valid Acc:86.30 %
# Epoch:28/100 	 Train Loss:0.2759 Valid Loss:0.4531 	 Train Acc:90.16 %  Valid Acc:86.22 %
# Epoch:29/100 	 Train Loss:0.2694 Valid Loss:0.4874 	 Train Acc:90.55 %  Valid Acc:85.21 %
# Epoch:30/100 	 Train Loss:0.2687 Valid Loss:0.4503 	 Train Acc:90.57 %  Valid Acc:86.23 %
# Epoch:31/100 	 Train Loss:0.2627 Valid Loss:0.4481 	 Train Acc:90.72 %  Valid Acc:86.48 %
# Epoch:32/100 	 Train Loss:0.2591 Valid Loss:0.4506 	 Train Acc:90.88 %  Valid Acc:86.38 %
# Epoch:33/100 	 Train Loss:0.2504 Valid Loss:0.4482 	 Train Acc:91.22 %  Valid Acc:86.40 %
# Epoch:34/100 	 Train Loss:0.2514 Valid Loss:0.4470 	 Train Acc:91.24 %  Valid Acc:86.28 %
# Epoch:35/100 	 Train Loss:0.2496 Valid Loss:0.4553 	 Train Acc:91.14 %  Valid Acc:86.44 %
# Epoch:36/100 	 Train Loss:0.2463 Valid Loss:0.4606 	 Train Acc:91.27 %  Valid Acc:86.45 %
# Epoch:37/100 	 Train Loss:0.2377 Valid Loss:0.4825 	 Train Acc:91.57 %  Valid Acc:86.29 %
# Epoch:38/100 	 Train Loss:0.2371 Valid Loss:0.4610 	 Train Acc:91.59 %  Valid Acc:86.09 %
# Epoch:39/100 	 Train Loss:0.2334 Valid Loss:0.4730 	 Train Acc:91.68 %  Valid Acc:86.34 %
# Epoch:40/100 	 Train Loss:0.2303 Valid Loss:0.4611 	 Train Acc:91.96 %  Valid Acc:86.81 %
# Epoch:41/100 	 Train Loss:0.2029 Valid Loss:0.4463 	 Train Acc:92.88 %  Valid Acc:86.96 %
# Epoch:42/100 	 Train Loss:0.1940 Valid Loss:0.4487 	 Train Acc:93.21 %  Valid Acc:87.13 %
# Epoch:43/100 	 Train Loss:0.1934 Valid Loss:0.4532 	 Train Acc:93.25 %  Valid Acc:86.99 %
# Epoch:44/100 	 Train Loss:0.1882 Valid Loss:0.4600 	 Train Acc:93.49 %  Valid Acc:86.96 %
# Epoch:45/100 	 Train Loss:0.1923 Valid Loss:0.4569 	 Train Acc:93.37 %  Valid Acc:87.11 %
# Epoch:46/100 	 Train Loss:0.1879 Valid Loss:0.4562 	 Train Acc:93.40 %  Valid Acc:86.86 %
# Epoch:47/100 	 Train Loss:0.1850 Valid Loss:0.4514 	 Train Acc:93.41 %  Valid Acc:87.25 %
# Epoch:48/100 	 Train Loss:0.1820 Valid Loss:0.4563 	 Train Acc:93.53 %  Valid Acc:87.10 %
# Epoch:49/100 	 Train Loss:0.1815 Valid Loss:0.4607 	 Train Acc:93.56 %  Valid Acc:87.20 %
# Epoch:50/100 	 Train Loss:0.1821 Valid Loss:0.4629 	 Train Acc:93.50 %  Valid Acc:87.07 %
# Epoch:51/100 	 Train Loss:0.1794 Valid Loss:0.4683 	 Train Acc:93.69 %  Valid Acc:87.17 %
# Epoch:52/100 	 Train Loss:0.1778 Valid Loss:0.4607 	 Train Acc:93.77 %  Valid Acc:87.36 %
# Epoch:53/100 	 Train Loss:0.1764 Valid Loss:0.4625 	 Train Acc:93.87 %  Valid Acc:86.99 %
# Epoch:54/100 	 Train Loss:0.1754 Valid Loss:0.4735 	 Train Acc:93.81 %  Valid Acc:87.34 %
# Epoch:55/100 	 Train Loss:0.1711 Valid Loss:0.4573 	 Train Acc:93.88 %  Valid Acc:87.19 %
# Epoch:56/100 	 Train Loss:0.1727 Valid Loss:0.4664 	 Train Acc:93.83 %  Valid Acc:87.26 %
# Epoch:57/100 	 Train Loss:0.1733 Valid Loss:0.4665 	 Train Acc:93.93 %  Valid Acc:87.25 %
# Epoch:58/100 	 Train Loss:0.1718 Valid Loss:0.4688 	 Train Acc:94.03 %  Valid Acc:87.13 %
# Epoch:59/100 	 Train Loss:0.1669 Valid Loss:0.4829 	 Train Acc:94.11 %  Valid Acc:87.06 %
# Epoch:60/100 	 Train Loss:0.1655 Valid Loss:0.4792 	 Train Acc:94.12 %  Valid Acc:87.22 %
# Epoch:61/100 	 Train Loss:0.1568 Valid Loss:0.4729 	 Train Acc:94.46 %  Valid Acc:87.32 %
# Epoch:62/100 	 Train Loss:0.1582 Valid Loss:0.4726 	 Train Acc:94.39 %  Valid Acc:87.38 %
# Epoch:63/100 	 Train Loss:0.1535 Valid Loss:0.4782 	 Train Acc:94.63 %  Valid Acc:87.25 %
# Epoch:64/100 	 Train Loss:0.1568 Valid Loss:0.4800 	 Train Acc:94.46 %  Valid Acc:87.29 %
# Epoch:65/100 	 Train Loss:0.1519 Valid Loss:0.4772 	 Train Acc:94.67 %  Valid Acc:87.35 %
# Epoch:66/100 	 Train Loss:0.1521 Valid Loss:0.4851 	 Train Acc:94.67 %  Valid Acc:87.12 %
# Epoch:67/100 	 Train Loss:0.1536 Valid Loss:0.4811 	 Train Acc:94.52 %  Valid Acc:87.29 %
# Epoch:68/100 	 Train Loss:0.1522 Valid Loss:0.4885 	 Train Acc:94.59 %  Valid Acc:87.13 %
# Epoch:69/100 	 Train Loss:0.1492 Valid Loss:0.4844 	 Train Acc:94.73 %  Valid Acc:87.38 %
# Epoch:70/100 	 Train Loss:0.1496 Valid Loss:0.4822 	 Train Acc:94.65 %  Valid Acc:87.29 %
# Epoch:71/100 	 Train Loss:0.1502 Valid Loss:0.4858 	 Train Acc:94.57 %  Valid Acc:87.35 %
# Epoch:72/100 	 Train Loss:0.1506 Valid Loss:0.4884 	 Train Acc:94.80 %  Valid Acc:87.12 %
# Epoch:73/100 	 Train Loss:0.1470 Valid Loss:0.4816 	 Train Acc:94.79 %  Valid Acc:87.22 %
# Epoch:74/100 	 Train Loss:0.1493 Valid Loss:0.4872 	 Train Acc:94.74 %  Valid Acc:87.24 %
# Epoch:75/100 	 Train Loss:0.1478 Valid Loss:0.4865 	 Train Acc:94.78 %  Valid Acc:87.53 %
# Epoch:76/100 	 Train Loss:0.1449 Valid Loss:0.4886 	 Train Acc:94.87 %  Valid Acc:87.28 %
# Epoch:77/100 	 Train Loss:0.1461 Valid Loss:0.4845 	 Train Acc:94.80 %  Valid Acc:87.33 %
# Epoch:78/100 	 Train Loss:0.1474 Valid Loss:0.4862 	 Train Acc:94.78 %  Valid Acc:87.25 %
# Epoch:79/100 	 Train Loss:0.1454 Valid Loss:0.4851 	 Train Acc:94.75 %  Valid Acc:87.42 %
# Epoch:80/100 	 Train Loss:0.1447 Valid Loss:0.4869 	 Train Acc:94.88 %  Valid Acc:87.32 %
# Epoch:81/100 	 Train Loss:0.1410 Valid Loss:0.4890 	 Train Acc:95.09 %  Valid Acc:87.43 %
# Epoch:82/100 	 Train Loss:0.1414 Valid Loss:0.4879 	 Train Acc:95.01 %  Valid Acc:87.54 %
# Epoch:83/100 	 Train Loss:0.1403 Valid Loss:0.4908 	 Train Acc:94.95 %  Valid Acc:87.45 %
# Epoch:84/100 	 Train Loss:0.1414 Valid Loss:0.4927 	 Train Acc:94.87 %  Valid Acc:87.36 %
# Epoch:85/100 	 Train Loss:0.1409 Valid Loss:0.4893 	 Train Acc:94.93 %  Valid Acc:87.54 %
# Epoch:86/100 	 Train Loss:0.1381 Valid Loss:0.4912 	 Train Acc:95.16 %  Valid Acc:87.48 %
# Epoch:87/100 	 Train Loss:0.1393 Valid Loss:0.4894 	 Train Acc:95.09 %  Valid Acc:87.52 %
# Epoch:88/100 	 Train Loss:0.1409 Valid Loss:0.4896 	 Train Acc:94.90 %  Valid Acc:87.45 %
# Epoch:89/100 	 Train Loss:0.1375 Valid Loss:0.4883 	 Train Acc:95.12 %  Valid Acc:87.44 %
# Epoch:90/100 	 Train Loss:0.1413 Valid Loss:0.4909 	 Train Acc:94.97 %  Valid Acc:87.39 %
# Epoch:91/100 	 Train Loss:0.1379 Valid Loss:0.4930 	 Train Acc:95.11 %  Valid Acc:87.31 %
# Epoch:92/100 	 Train Loss:0.1383 Valid Loss:0.4933 	 Train Acc:95.09 %  Valid Acc:87.56 %
# Epoch:93/100 	 Train Loss:0.1358 Valid Loss:0.4933 	 Train Acc:95.18 %  Valid Acc:87.51 %
# Epoch:94/100 	 Train Loss:0.1381 Valid Loss:0.4945 	 Train Acc:95.14 %  Valid Acc:87.35 %
# Epoch:95/100 	 Train Loss:0.1390 Valid Loss:0.4925 	 Train Acc:95.10 %  Valid Acc:87.46 %
# Epoch:96/100 	 Train Loss:0.1363 Valid Loss:0.4943 	 Train Acc:95.07 %  Valid Acc:87.55 %
# Epoch:97/100 	 Train Loss:0.1391 Valid Loss:0.4949 	 Train Acc:94.99 %  Valid Acc:87.47 %
# Epoch:98/100 	 Train Loss:0.1387 Valid Loss:0.4961 	 Train Acc:95.06 %  Valid Acc:87.58 %
# Epoch:99/100 	 Train Loss:0.1368 Valid Loss:0.4958 	 Train Acc:95.20 %  Valid Acc:87.44 %
# [I 2024-09-29 13:41:15,224] Trial 19 finished with value: 87.46000000000001 and parameters: {'sigma_1': 4.278433278421295, 'sigma_2': 3.371086291845102, 'sigma_3': 4.1453050307834065, 'sigma_4': 3.7808569514257533, 'sigma_5': 3.4731121517127894, 'sigma_6': 3.442913761000586, 'sigma_7': 4.081345804209523, 'sigma_8': 5.533530113840385, 'sigma_9': 3.3353561409624635, 'sigma_10': 4.215631028027772, 'sigma_11': 2.482728392351857, 'sigma_12': 3.659540972160993, 'sigma_13': 4.013921412857482}. Best is trial 5 with value: 87.79.
# Epoch:100/100 	 Train Loss:0.1399 Valid Loss:0.4941 	 Train Acc:95.01 %  Valid Acc:87.46 %
# Best trial:
#   Value:  87.79
#   Params:
#     sigma_1: 3.9858475313312236
#     sigma_2: 5.2531078598099485
#     sigma_3: 5.089494814479712
#     sigma_4: 2.8074438391635086
#     sigma_5: 2.2022404256941384
#     sigma_6: 2.8515413976412893
#     sigma_7: 4.4484960003692535
#     sigma_8: 5.070710170952079
#     sigma_9: 2.894160101529802
#     sigma_10: 4.369134671365424
#     sigma_11: 2.698460011357618
#     sigma_12: 2.9889064668682894
#     sigma_13: 2.7814107653406643

# %%
import random
from torchvision import datasets, transforms
import torch.optim as optim
import torch.nn as nn
import pandas as pd
import numpy as np
import torch
from torch.autograd import Variable
import torch.nn.functional as F
import torch.utils.data as Data

import matplotlib.pyplot as plt
# %matplotlib inline
import math
import torchvision
import torchvision.transforms as transforms
import optuna  # 载入 optuna 优化包

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# 图像预处理模块
transform = transforms.Compose([
    transforms.Pad(4),
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32),
    transforms.ToTensor()
])

# CIFAR-10 数据集
train_dataset = torchvision.datasets.CIFAR10(root='../../data/',
                                             train=True,
                                             transform=transform,
                                             download=True)

test_dataset = torchvision.datasets.CIFAR10(root='../../data/',
                                            train=False,
                                            transform=transforms.ToTensor())

# 数据加载器
train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                           batch_size=100,
                                           shuffle=True)

test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                          batch_size=100,
                                          shuffle=False)

# 自定义 Raylu 激活函数类
class Raylu(nn.Module):
    def __init__(self):
        super().__init__()
        self.sigma = nn.Parameter(2 * torch.randn(1))  # 可学习参数 sigma

    def forward(self, input):
        x = torch.where(input >= 0, input, input * torch.exp(-input ** 2 / self.sigma ** 2 / 2))
        return x

# 3x3 卷积层
def conv3x3(in_channels, out_channels, stride=1):
    return nn.Conv2d(in_channels, out_channels, kernel_size=3,
                     stride=stride, padding=1, bias=False)

# 残差块
class ResidualBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1, downsample=None):
        super(ResidualBlock, self).__init__()
        self.conv1 = conv3x3(in_channels, out_channels, stride)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.Raylu1 = Raylu()
        self.Raylu2 = Raylu()
        self.conv2 = conv3x3(out_channels, out_channels)
        self.bn2 = nn.BatchNorm2d(out_channels)
        self.downsample = downsample

    def forward(self, x):
        residual = x
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.Raylu1(out)
        out = self.conv2(out)
        out = self.bn2(out)
        if self.downsample:
            residual = self.downsample(x)
        out += residual
        out = self.Raylu2(out)
        return out

# ResNet 模型
class ResNet(nn.Module):
    def __init__(self, block, layers, num_classes=10):
        super(ResNet, self).__init__()
        self.in_channels = 16
        self.conv = conv3x3(3, 16)
        self.bn = nn.BatchNorm2d(16)
        self.Raylu3 = Raylu()
        self.layer1 = self.make_layer(block, 16, layers[0])
        self.layer2 = self.make_layer(block, 32, layers[1], 2)
        self.layer3 = self.make_layer(block, 64, layers[2], 2)
        self.avg_pool = nn.AvgPool2d(8)
        self.fc = nn.Linear(64, num_classes)

    def make_layer(self, block, out_channels, blocks, stride=1):
        downsample = None
        if (stride != 1) or (self.in_channels != out_channels):
            downsample = nn.Sequential(
                conv3x3(self.in_channels, out_channels, stride=stride),
                nn.BatchNorm2d(out_channels))
        layers = []
        layers.append(block(self.in_channels, out_channels, stride, downsample))
        self.in_channels = out_channels
        for i in range(1, blocks):
            layers.append(block(out_channels, out_channels))
        return nn.Sequential(*layers)

    def forward(self, x):
        out = self.conv(x)
        out = self.bn(out)
        out = self.Raylu3(out)
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.avg_pool(out)
        out = out.view(out.size(0), -1)
        out = self.fc(out)
        return out

# 模型实例化
model = ResNet(ResidualBlock, [2, 2, 2]).to(device)

# 损失函数和优化器
criterion = nn.CrossEntropyLoss()
learning_rate = 0.001
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# 初始化 Raylu 激活函数中的 sigma 参数
z = model.Raylu3.sigma
nn.init.constant_(z, 6)
z101 = model.layer1[0].Raylu1.sigma
nn.init.constant_(z101, 4)
z102 = model.layer1[0].Raylu2.sigma
nn.init.constant_(z102, 4)
z111 = model.layer1[1].Raylu1.sigma
nn.init.constant_(z111, 3)
z112 = model.layer1[1].Raylu2.sigma
nn.init.constant_(z112, 3)
z201 = model.layer2[0].Raylu1.sigma
nn.init.constant_(z201, 5)
z202 = model.layer2[0].Raylu2.sigma
nn.init.constant_(z202, 5)
z211 = model.layer2[1].Raylu1.sigma
nn.init.constant_(z211, 5)
z212 = model.layer2[1].Raylu2.sigma
nn.init.constant_(z212, 5)
z301 = model.layer3[0].Raylu1.sigma
nn.init.constant_(z301, 2)
z302 = model.layer3[0].Raylu2.sigma
nn.init.constant_(z302, 4)
z311 = model.layer3[1].Raylu1.sigma
nn.init.constant_(z311, 2)
z312 = model.layer3[1].Raylu2.sigma
nn.init.constant_(z312, 3)

# 更新学习率函数
def update_lr(optimizer, lr):
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

# 训练模型
total_step = len(train_loader)
curr_lr = learning_rate

history = {'train_loss': [], 'valid_loss': [], 'train_acc': [], 'valid_acc': []}
num_epochs = 80

for epoch in range(num_epochs):
    train_loss, train_correct = 0.0, 0
    for i, (images, labels) in enumerate(train_loader):
        images, labels = images.to(device), labels.to(device)

        # 前向传播
        outputs = model(images)
        loss = criterion(outputs, labels)

        # 反向传播与优化
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        train_loss += loss.item() * images.size(0)
        scores, predictions = torch.max(outputs.data, 1)
        train_correct += (predictions == labels).sum().item()

    # 每 20 轮衰减学习率
    if (epoch + 1) % 20 == 0:
        curr_lr /= 3
        update_lr(optimizer, curr_lr)

    valid_loss, val_correct = 0.0, 0
    model.eval()
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        loss = criterion(outputs, labels)
        valid_loss += loss.item() * images.size(0)
        scores, predictions = torch.max(outputs.data, 1)
        val_correct += (predictions == labels).sum().item()

    train_loss /= len(train_loader.sampler)
    train_acc = train_correct / len(train_loader.sampler) * 100
    valid_loss /= len(test_loader.sampler)
    valid_acc = val_correct / len(test_loader.sampler) * 100

    print(f"Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.4f}, Valid Loss: {valid_loss:.4f}, "
          f"Train Acc: {train_acc:.2f}%, Valid Acc: {valid_acc:.2f}%")

    history['train_loss'].append(train_loss)
    history['valid_loss'].append(valid_loss)
    history['train_acc'].append(train_acc)
    history['valid_acc'].append(valid_acc)
# Out:
# Files already downloaded and verified
# Epoch [1/80], Train Loss: 1.6510, Valid Loss: 1.4344, Train Acc: 38.62%, Valid Acc: 47.45%
# Epoch [2/80], Train Loss: 1.2280, Valid Loss: 1.0794, Train Acc: 55.61%, Valid Acc: 61.53%
# Epoch [3/80], Train Loss: 0.9942, Valid Loss: 0.9287, Train Acc: 64.46%, Valid Acc: 67.08%
# Epoch [4/80], Train Loss: 0.8649, Valid Loss: 0.8015, Train Acc: 69.40%, Valid Acc: 71.98%
# Epoch [5/80], Train Loss: 0.7708, Valid Loss: 0.7369, Train Acc: 72.96%, Valid Acc: 74.62%
# Epoch [6/80], Train Loss: 0.6855, Valid Loss: 0.7360, Train Acc: 76.24%, Valid Acc: 75.53%
# Epoch [7/80], Train Loss: 0.6239, Valid Loss: 0.6345, Train Acc: 78.12%, Valid Acc: 78.65%
# Epoch [8/80], Train Loss: 0.5756, Valid Loss: 0.6337, Train Acc: 79.75%, Valid Acc: 78.94%
# Epoch [9/80], Train Loss: 0.5403, Valid Loss: 0.5981, Train Acc: 81.07%, Valid Acc: 79.79%
# Epoch [10/80], Train Loss: 0.5121, Valid Loss: 0.5507, Train Acc: 82.20%, Valid Acc: 81.54%
# Epoch [11/80], Train Loss: 0.4869, Valid Loss: 0.5835, Train Acc: 83.08%, Valid Acc: 80.85%
# Epoch [12/80], Train Loss: 0.4622, Valid Loss: 0.5369, Train Acc: 83.80%, Valid Acc: 81.94%
# Epoch [13/80], Train Loss: 0.4418, Valid Loss: 0.5724, Train Acc: 84.65%, Valid Acc: 81.39%
# Epoch [14/80], Train Loss: 0.4317, Valid Loss: 0.5268, Train Acc: 84.91%, Valid Acc: 82.61%
# Epoch [15/80], Train Loss: 0.4122, Valid Loss: 0.5258, Train Acc: 85.67%, Valid Acc: 82.38%
# Epoch [16/80], Train Loss: 0.3994, Valid Loss: 0.4942, Train Acc: 86.10%, Valid Acc: 84.09%
# Epoch [17/80], Train Loss: 0.3815, Valid Loss: 0.5151, Train Acc: 86.59%, Valid Acc: 83.04%
# Epoch [18/80], Train Loss: 0.3744, Valid Loss: 0.4892, Train Acc: 86.95%, Valid Acc: 84.07%
# Epoch [19/80], Train Loss: 0.3591, Valid Loss: 0.4996, Train Acc: 87.37%, Valid Acc: 84.04%
# Epoch [20/80], Train Loss: 0.3583, Valid Loss: 0.4683, Train Acc: 87.24%, Valid Acc: 84.61%
# Epoch [21/80], Train Loss: 0.2786, Valid Loss: 0.4205, Train Acc: 90.24%, Valid Acc: 86.24%
# Epoch [22/80], Train Loss: 0.2583, Valid Loss: 0.4176, Train Acc: 90.93%, Valid Acc: 86.65%
# Epoch [23/80], Train Loss: 0.2520, Valid Loss: 0.4282, Train Acc: 91.23%, Valid Acc: 86.59%
# Epoch [24/80], Train Loss: 0.2452, Valid Loss: 0.4373, Train Acc: 91.49%, Valid Acc: 86.14%
# Epoch [25/80], Train Loss: 0.2386, Valid Loss: 0.4478, Train Acc: 91.59%, Valid Acc: 86.27%
# Epoch [26/80], Train Loss: 0.2328, Valid Loss: 0.4363, Train Acc: 91.66%, Valid Acc: 86.65%
# Epoch [27/80], Train Loss: 0.2277, Valid Loss: 0.4411, Train Acc: 91.88%, Valid Acc: 86.82%
# Epoch [28/80], Train Loss: 0.2222, Valid Loss: 0.4349, Train Acc: 92.10%, Valid Acc: 86.51%
# Epoch [29/80], Train Loss: 0.2205, Valid Loss: 0.4398, Train Acc: 92.20%, Valid Acc: 86.51%
# Epoch [30/80], Train Loss: 0.2139, Valid Loss: 0.4463, Train Acc: 92.49%, Valid Acc: 86.15%
# Epoch [31/80], Train Loss: 0.2122, Valid Loss: 0.4612, Train Acc: 92.49%, Valid Acc: 86.10%
# Epoch [32/80], Train Loss: 0.2068, Valid Loss: 0.4402, Train Acc: 92.79%, Valid Acc: 86.87%
# Epoch [33/80], Train Loss: 0.2040, Valid Loss: 0.4379, Train Acc: 92.93%, Valid Acc: 87.09%
# Epoch [34/80], Train Loss: 0.1990, Valid Loss: 0.4554, Train Acc: 92.99%, Valid Acc: 86.51%
# Epoch [35/80], Train Loss: 0.1948, Valid Loss: 0.4505, Train Acc: 93.03%, Valid Acc: 86.58%
# Epoch [36/80], Train Loss: 0.1942, Valid Loss: 0.4512, Train Acc: 93.07%, Valid Acc: 87.05%
# Epoch [37/80], Train Loss: 0.1916, Valid Loss: 0.4732, Train Acc: 93.08%, Valid Acc: 87.02%
# Epoch [38/80], Train Loss: 0.1863, Valid Loss: 0.4576, Train Acc: 93.38%, Valid Acc: 87.00%
# Epoch [39/80], Train Loss: 0.1833, Valid Loss: 0.4648, Train Acc: 93.41%, Valid Acc: 86.70%
# Epoch [40/80], Train Loss: 0.1805, Valid Loss: 0.4694, Train Acc: 93.62%, Valid Acc: 86.64%
# Epoch [41/80], Train Loss: 0.1540, Valid Loss: 0.4456, Train Acc: 94.61%, Valid Acc: 87.48%
# Epoch [42/80], Train Loss: 0.1452, Valid Loss: 0.4549, Train Acc: 94.81%, Valid Acc: 87.31%
# Epoch [43/80], Train Loss: 0.1442, Valid Loss: 0.4597, Train Acc: 94.91%, Valid Acc: 87.20%
# Epoch [44/80], Train Loss: 0.1415, Valid Loss: 0.4582, Train Acc: 95.02%, Valid Acc: 87.31%
# Epoch [45/80], Train Loss: 0.1412, Valid Loss: 0.4517, Train Acc: 94.98%, Valid Acc: 87.39%
# Epoch [46/80], Train Loss: 0.1379, Valid Loss: 0.4697, Train Acc: 95.13%, Valid Acc: 87.26%
# Epoch [47/80], Train Loss: 0.1372, Valid Loss: 0.4740, Train Acc: 95.17%, Valid Acc: 87.13%
# Epoch [48/80], Train Loss: 0.1355, Valid Loss: 0.4707, Train Acc: 95.18%, Valid Acc: 87.19%
# Epoch [49/80], Train Loss: 0.1359, Valid Loss: 0.4719, Train Acc: 95.17%, Valid Acc: 87.09%
# Epoch [50/80], Train Loss: 0.1309, Valid Loss: 0.4788, Train Acc: 95.42%, Valid Acc: 87.31%
# Epoch [51/80], Train Loss: 0.1317, Valid Loss: 0.4872, Train Acc: 95.34%, Valid Acc: 87.21%
# Epoch [52/80], Train Loss: 0.1304, Valid Loss: 0.4803, Train Acc: 95.36%, Valid Acc: 87.26%
# Epoch [53/80], Train Loss: 0.1271, Valid Loss: 0.4961, Train Acc: 95.52%, Valid Acc: 87.13%
# Epoch [54/80], Train Loss: 0.1281, Valid Loss: 0.4775, Train Acc: 95.45%, Valid Acc: 87.22%
# Epoch [55/80], Train Loss: 0.1255, Valid Loss: 0.4952, Train Acc: 95.55%, Valid Acc: 86.85%
# Epoch [56/80], Train Loss: 0.1233, Valid Loss: 0.4834, Train Acc: 95.69%, Valid Acc: 87.23%
# Epoch [57/80], Train Loss: 0.1221, Valid Loss: 0.4805, Train Acc: 95.63%, Valid Acc: 87.02%
# Epoch [58/80], Train Loss: 0.1225, Valid Loss: 0.4906, Train Acc: 95.71%, Valid Acc: 87.11%
# Epoch [59/80], Train Loss: 0.1193, Valid Loss: 0.4982, Train Acc: 95.71%, Valid Acc: 87.21%
# Epoch [60/80], Train Loss: 0.1181, Valid Loss: 0.4981, Train Acc: 95.76%, Valid Acc: 87.08%
# Epoch [61/80], Train Loss: 0.1113, Valid Loss: 0.4939, Train Acc: 96.01%, Valid Acc: 87.24%
# Epoch [62/80], Train Loss: 0.1076, Valid Loss: 0.5002, Train Acc: 96.22%, Valid Acc: 87.24%
# Epoch [63/80], Train Loss: 0.1084, Valid Loss: 0.5005, Train Acc: 96.24%, Valid Acc: 87.08%
# Epoch [64/80], Train Loss: 0.1101, Valid Loss: 0.4942, Train Acc: 96.09%, Valid Acc: 87.33%
# Epoch [65/80], Train Loss: 0.1067, Valid Loss: 0.4969, Train Acc: 96.19%, Valid Acc: 87.14%
# Epoch [66/80], Train Loss: 0.1078, Valid Loss: 0.4998, Train Acc: 96.11%, Valid Acc: 87.20%
# Epoch [67/80], Train Loss: 0.1057, Valid Loss: 0.4976, Train Acc: 96.22%, Valid Acc: 87.31%
# Epoch [68/80], Train Loss: 0.1037, Valid Loss: 0.5048, Train Acc: 96.35%, Valid Acc: 87.25%
# Epoch [69/80], Train Loss: 0.1032, Valid Loss: 0.5085, Train Acc: 96.33%, Valid Acc: 87.23%
# Epoch [70/80], Train Loss: 0.1047, Valid Loss: 0.5094, Train Acc: 96.31%, Valid Acc: 87.23%
# Epoch [71/80], Train Loss: 0.1046, Valid Loss: 0.5113, Train Acc: 96.31%, Valid Acc: 87.08%
# Epoch [72/80], Train Loss: 0.1025, Valid Loss: 0.5105, Train Acc: 96.41%, Valid Acc: 87.23%
# Epoch [73/80], Train Loss: 0.0999, Valid Loss: 0.5088, Train Acc: 96.46%, Valid Acc: 87.05%
# Epoch [74/80], Train Loss: 0.1021, Valid Loss: 0.5177, Train Acc: 96.35%, Valid Acc: 87.08%
# Epoch [75/80], Train Loss: 0.1031, Valid Loss: 0.5081, Train Acc: 96.37%, Valid Acc: 87.04%
# Epoch [76/80], Train Loss: 0.1019, Valid Loss: 0.5097, Train Acc: 96.36%, Valid Acc: 87.12%
# Epoch [77/80], Train Loss: 0.1009, Valid Loss: 0.5137, Train Acc: 96.42%, Valid Acc: 87.03%
# Epoch [78/80], Train Loss: 0.0970, Valid Loss: 0.5161, Train Acc: 96.59%, Valid Acc: 87.21%
# Epoch [79/80], Train Loss: 0.0990, Valid Loss: 0.5138, Train Acc: 96.56%, Valid Acc: 86.98%
# Epoch [80/80], Train Loss: 0.1004, Valid Loss: 0.5124, Train Acc: 96.44%, Valid Acc: 87.23%
